# %%
import pandas as pd

# %%
genalg_rastrigin_data = pd.read_csv('cust_rastrigin_upd.csv')
genalg_rastrigin_data.describe().T
# Out:
#                                      count        mean         std
# Медиана значения функции Растригина   30.0    0.262242    0.487319  \
# Мода лучшей итерации                  30.0  100.000000    0.000000
# Медиана времени до лучшей итерации    30.0    2.020458    1.031485
# population_size                       30.0  309.466667  120.448797
# offspring_ratio                       30.0    2.209862    0.434540
# mutation_rate                         30.0    0.281287    0.109322
# mutation_strength                     30.0    0.302678    0.139458
# mutation_percent_genes                30.0    0.152699    0.026704
# elite_fraction                        30.0    0.135685    0.044934
#
#                                             min         25%         50%
# Медиана значения функции Растригина    0.003097    0.020535    0.096126  \
# Мода лучшей итерации                 100.000000  100.000000  100.000000
# Медиана времени до лучшей итерации     0.516509    1.244164    1.736813
# ...

# %%
genalg_shvefel_data = pd.read_csv('cust_shvefel_upd.csv')
genalg_shvefel_data.describe().T
# Out:
#                                     count        mean        std         min
# Медиана значения функции Швефеля     32.0    0.117151   0.217345    0.007330  \
# Мода лучшей итерации                 32.0  398.656250   7.601398  357.000000
# Медиана времени до лучшей итерации   32.0    6.418940   2.958408    2.140510
# population_size                      32.0  250.156250  94.990699  100.000000
# offspring_ratio                      32.0    2.372534   0.404771    1.517605
# mutation_rate                        32.0    0.335659   0.125876    0.106020
# mutation_strength                    32.0    0.307530   0.121428    0.109397
# mutation_percent_genes               32.0    0.145614   0.026316    0.111721
# elite_fraction                       32.0    0.123608   0.041467    0.051635
#
#                                            25%         50%         75%
# Медиана значения функции Швефеля      0.028140    0.048981    0.125291  \
# ...

# %%
pygad_rastrigin_data = pd.read_csv('pygad_rastrigin.csv')
pygad_rastrigin_data.describe().T
# Out:
#                                      count        mean         std
# Медиана значения функции Растригина   30.0   61.270656   96.044538  \
# Мода лучшей итерации                  30.0   59.166667   39.226208
# Медиана времени до лучшей итерации    30.0    9.205164    7.926632
# num_parents_mating                    30.0  186.800000   96.248744
# sol_per_pop                           30.0  275.133333  127.438351
# num_genes                             30.0   19.066667    8.287645
# mutation_percent_genes                30.0   24.293092   15.004136
# random_mutation_min_val               30.0   -4.352784    2.986739
# random_mutation_max_val               30.0    4.857614    2.968960
# keep_parents                          30.0    0.479301    0.303430
#
#                                             min         25%         50%
# Медиана значения функции Растригина    0.025009    2.713736   21.148338  \
# Мода лучшей итерации                   1.000000   19.500000   70.000000
# ...

# %%
pygad_shvefel_data = pd.read_csv('pygad_shvefel.csv')
pygad_shvefel_data.describe().T
# Out:
#                                     count         mean         std
# Медиана значения функции Швефеля     30.0   339.150882  980.411377  \
# Мода лучшей итерации                 30.0    50.833333   34.562371
# Медиана времени до лучшей итерации   30.0    30.996559   39.417985
# num_parents_mating                   30.0   714.533333  557.298826
# sol_per_pop                          30.0  1457.833333  795.746064
# mutation_percent_genes               30.0    23.978463   13.316596
# random_mutation_min_val              30.0    -5.655595    2.891383
# random_mutation_max_val              30.0     4.982281    3.269902
# keep_parents                         30.0     0.437327    0.314965
# num_genes                            30.0    18.100000    7.087386
#
#                                            min         25%          50%
# Медиана значения функции Швефеля      0.004623    0.182056     4.333095  \
# Мода лучшей итерации                  4.000000   18.500000    48.000000
# ...

# %%
deap_rastrigin_data = pd.read_csv('deap_rastrigin.csv')
deap_rastrigin_data.describe().T
# Out:
#                                      count        mean         std
# Медиана значения функции Растригина   30.0    0.702546    1.949177  \
# Мода лучшей итерации                  30.0  164.066667  204.365280
# Медиана времени до лучшей итерации    30.0    0.011405    0.004340
# Population Size                       30.0  295.500000  107.053886
# Mutation Rate                         30.0    0.242539    0.136165
# Crossover Rate                        30.0    0.285545    0.130777
# Elitism Fraction                      30.0    0.108568    0.050241
# Alpha                                 30.0    0.513628    0.250859
# Mu                                    30.0   -0.107900    0.604062
# Sigma                                 30.0    0.455912    0.296519
# Tournament Size                       30.0    3.633333    0.964305
#
#                                             min         25%         50%
# Медиана значения функции Растригина    0.000000    0.000000    0.000000  \
# ...

# %%
deap_shvefel_data = pd.read_csv('deap_shvefel.csv')
deap_shvefel_data.describe().T
# Out:
#                                     count        mean         std         min
# Медиана значения функции Швефеля     30.0  706.477297  750.207250    0.000127  \
# Мода лучшей итерации                 30.0  235.600000  227.342306    1.000000
# Медиана времени до лучшей итерации   30.0    6.026629    7.661809    0.171506
# Population Size                      30.0  283.766667  114.585816  112.000000
# Mutation Rate                        30.0    0.271129    0.148203    0.013304
# Crossover Rate                       30.0    0.268523    0.149668    0.012321
# Elitism Fraction                     30.0    0.103332    0.056600    0.013096
# Alpha                                30.0    0.470139    0.229145    0.080719
# Mu                                   30.0   -0.016602    0.519148   -0.982763
# Sigma                                30.0    0.431859    0.272611    0.045287
# Tournament Size                      30.0    3.366667    1.272612    2.000000
#
# ...

# %%
opt_rastrigin_data = pd.read_csv('opt_rastrigin.csv')
opt_rastrigin_data.describe().T
# Out:
#                                     count        mean           std
# Значение оптимальной функции         30.0   44.137129  7.226896e-15  \
# Оптимальная итерация                 30.0  483.000000  0.000000e+00
# Время до оптимальной итерации, сек   30.0   91.602870  7.336829e+00
#
#                                            min         25%         50%
# Значение оптимальной функции         44.137129   44.137129   44.137129  \
# Оптимальная итерация                483.000000  483.000000  483.000000
# Время до оптимальной итерации, сек   78.660397   85.824264   90.484160
#
#                                            75%         max
# Значение оптимальной функции         44.137129   44.137129
# Оптимальная итерация                483.000000  483.000000
# Время до оптимальной итерации, сек   95.430072  109.991766

# %%
opt_shvefel_data = pd.read_csv('opt_shvefel.csv')
opt_shvefel_data.describe().T
# Out:
#                                     count        mean           std
# Значение оптимальной функции         30.0  683.408493  2.312607e-13  \
# Оптимальная итерация                 30.0  677.000000  0.000000e+00
# Время до оптимальной итерации, сек   30.0   93.834247  7.630792e+00
#
#                                            min         25%         50%
# Значение оптимальной функции        683.408493  683.408493  683.408493  \
# Оптимальная итерация                677.000000  677.000000  677.000000
# Время до оптимальной итерации, сек   76.019600   88.879991   94.692301
#
#                                            75%         max
# Значение оптимальной функции        683.408493  683.408493
# Оптимальная итерация                677.000000  677.000000
# Время до оптимальной итерации, сек   98.512070  107.507377

# %%
genalg_houses_data = pd.read_csv('cust_houses.csv')
genalg_houses_data.describe().T
# Out:
#                                 count           mean          std
# Median MSE                       29.0  507197.770980  1066.702968  \
# Mode Best Generation             29.0      27.379310     4.427300
# Median Time to Best Generation   29.0    1330.341155  1490.241527
# Population Size                  29.0      75.206897    91.757981
# Mutation Rate                    29.0       0.321960     0.107439
# Offspring Ratio                  29.0       2.279213     0.430640
# Mutation Strength                29.0       0.272582     0.105225
# Mutation Percent Genes           29.0       0.153147     0.028249
# Elite Fraction                   29.0       0.132252     0.043047
#
#                                           min            25%            50%
# Median MSE                      505527.234587  506583.331512  507022.906834  \
# Mode Best Generation                17.000000      26.000000      30.000000
# Median Time to Best Generation     124.057993     639.520506     800.336860
# ...

# %%
deap_houses_data = pd.read_csv('deap_houses.csv')
deap_houses_data.describe().T
# Out:
#                                     count           mean          std
# Медиана MSE                          29.0  506131.877901  1630.478855  \
# Мода лучшей итерации                 29.0       9.000000     7.348469
# Медиана времени до лучшей итерации   29.0     143.291704   111.365230
# Population Size                      29.0     277.137931   134.387692
# Mutation Rate                        29.0       0.262564     0.140500
# Crossover Rate                       29.0       0.283615     0.143545
# Elitism Fraction                     29.0       0.091816     0.056897
# Alpha                                29.0       0.487912     0.219818
# Mu                                   29.0       0.007949     0.687843
# Sigma                                29.0       0.491450     0.307555
# Tournament Size                      29.0       3.551724     1.212618
#
#                                               min            25%
# ...

# %%
pygad_houses_data = pd.read_csv('pygad_houses.csv')
pygad_houses_data.describe().T
# Out:
#                                     count           mean          std
# Медиана MSE                          30.0  508689.000813  3607.180582  \
# Мода лучшей итерации                 30.0      20.000000     0.000000
# Медиана времени до лучшей итерации   30.0     292.892840   244.431831
# num_parents_mating                   30.0       7.366667     2.326509
# sol_per_pop                          30.0      52.266667    29.411390
# mutation_percent_genes               30.0      25.093171    13.853448
# mutation_num_genes                   30.0       2.066667     0.907187
# random_mutation_min_val              30.0      -0.048282     0.027623
# random_mutation_max_val              30.0       0.052511     0.031266
# num_genes                            30.0       6.000000     0.000000
#
#                                               min            25%
# Медиана MSE                         503582.667955  506974.483128  \
# ...

# %%
optuna_houses_data = pd.read_csv('opt_houses.csv')
optuna_houses_data.describe().T
# Out:
#                                     count           mean  std            min
# Лучшее значение MSE                   1.0  501628.548547  NaN  501628.548547  \
# Лучшая итерация                       1.0     231.000000  NaN     231.000000
# Время до лучшей итерации (секунды)    1.0     202.900064  NaN     202.900064
#
#                                               25%            50%
# Лучшее значение MSE                 501628.548547  501628.548547  \
# Лучшая итерация                        231.000000     231.000000
# Время до лучшей итерации (секунды)     202.900064     202.900064
#
#                                               75%            max
# Лучшее значение MSE                 501628.548547  501628.548547
# Лучшая итерация                        231.000000     231.000000
# Время до лучшей итерации (секунды)     202.900064     202.900064
