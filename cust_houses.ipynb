# %%
import random
import time
import numpy as np
import pandas as pd
from deap import base, creator, tools, algorithms
from sklearn.model_selection import cross_val_score
import lightgbm as lgb
from tqdm import tqdm
import gc
from pyDOE import lhs
import time

# Загрузка данных
data = pd.read_csv('houston_short_300.csv')
# data = data.sample(n=300, random_state=42)
# data.to_csv('houston_short_300.csv', index=False)
X = data[['Latitude', 'Longitude', 'Year Built', 'Beds', 'Baths', 'buildingSize', 'lotSize', 'PostalCode']]
y = data['Price']

# %%
import random
import numpy as np
import pandas as pd
import gc
import time
from pyDOE import lhs
from sklearn.model_selection import cross_val_score
import lightgbm as lgb

# Универсальная функция кэширования с возможностью очистки кэша
class CacheFunction:
    def __init__(self, func):
        self.func = func
        self.cache = {}

    def __call__(self, x):
        # Преобразуем массив в кортеж, чтобы использовать его в качестве ключа
        key = tuple(x) if isinstance(x, (list, np.ndarray)) else x
        if key in self.cache:
            return self.cache[key]
        result = self.func(x)
        self.cache[key] = result
        return result

    def clear_cache(self):
        self.cache.clear()


# Функция оценки модели LGBM с использованием MSE
def lgbm_function(individual):
    params = {
        'n_estimators': int(individual[0]),
        'max_depth': int(individual[1]),
        'num_leaves': int(individual[2]),
        'learning_rate': individual[3],
        'max_bin': int(individual[4]),
        'colsample_bytree': individual[5]
    }

    # Принудительная проверка и коррекция параметров перед запуском модели
    if params['colsample_bytree'] > 1.0:
        params['colsample_bytree'] = 1.0
    if params['learning_rate'] > 1.0:
        params['learning_rate'] = 1.0
    if params['learning_rate'] < 0.01:
        params['learning_rate'] = 0.01
    
    # Остальные параметры в зависимости от задачи можно добавить здесь

    # print(f"Запуск кросс-валидации LGBM с параметрами: {params}")
    
    model = lgb.LGBMRegressor(**params)
    scores = cross_val_score(model, X, y, cv=3, scoring='neg_mean_squared_error')
    mse = -np.mean(scores)
    return mse,


# Кэшированная версия функции
cached_objective_function = CacheFunction(lgbm_function)

# Ограничение значений после мутации и кроссинговера
def check_bounds(individual, param_ranges):
    # Для каждого параметра проверяем его допустимые границы
    for i in range(len(individual)):
        lower_bound = param_ranges[i][0]
        upper_bound = param_ranges[i][1]
        # Принудительно обрезаем значения, если они выходят за границы
        individual[i] = np.clip(individual[i], lower_bound, upper_bound)
    return individual






# Инициализация популяции (латинский гиперкуб или случайная инициализация)
# Инициализация популяции (латинский гиперкуб или случайная инициализация)
def initialize_population(pop_size, param_ranges):
    population = np.random.uniform([param[0] for param in param_ranges], [param[1] for param in param_ranges], (pop_size, len(param_ranges)))
    
    # Применяем check_bounds ко всей начальной популяции и преобразуем в массив NumPy
    population = np.array([check_bounds(ind, param_ranges) for ind in population])
    # print(f"Проверка популяции после инициализации: {population}")
    
    return population



def select_top_individuals_with_elitism(population, fitness_values, selection_percentage, elite_count=1):
    num_selected = int(len(population) * selection_percentage) - elite_count
    sorted_indices = np.argsort(fitness_values)

    # Преобразуем формы массивов с помощью np.squeeze(), чтобы избавиться от лишних осей
    elite_indices = np.squeeze(sorted_indices[:elite_count])
    elite_population = np.squeeze(population[elite_indices])
    elite_fitness = np.squeeze(fitness_values[elite_indices])

    selected_indices = np.squeeze(sorted_indices[elite_count:elite_count + num_selected])
    selected_population = np.squeeze(population[selected_indices])
    selected_fitness = np.squeeze(fitness_values[selected_indices])

    final_population = np.concatenate([elite_population, selected_population])
    final_fitness = np.concatenate([elite_fitness, selected_fitness])

    return final_population, final_fitness





# Скрещивание двух родителей
def crossover(parent1, parent2):
    return np.random.uniform(parent1, parent2)

# Создание потомков
def generate_offspring(selected_population, num_offspring):
    offspring = []
    for _ in range(num_offspring):
        parents = np.random.choice(len(selected_population), 2, replace=False)
        child = crossover(selected_population[parents[0]], selected_population[parents[1]])
        offspring.append(child)
    return np.array(offspring)

# Мутация потомков
def mutate(offspring, mutation_rate, mutation_strength, mutation_percent_genes, mutation_by_replacement, param_ranges):
    num_to_mutate = int(len(offspring) * mutation_rate)
    indices_to_mutate = np.random.choice(len(offspring), num_to_mutate, replace=False)
    for i in indices_to_mutate:
        num_genes_to_mutate = int(offspring.shape[1] * mutation_percent_genes)
        genes_to_mutate = np.random.choice(offspring.shape[1], num_genes_to_mutate, replace=False)
        for gene_idx in genes_to_mutate:
            if mutation_by_replacement:
                offspring[i, gene_idx] = np.random.uniform(param_ranges[gene_idx][0], param_ranges[gene_idx][1])
            else:
                mutation = np.random.uniform(-mutation_strength, mutation_strength) * (param_ranges[gene_idx][1] - param_ranges[gene_idx][0])
                offspring[i, gene_idx] += mutation
                # Применяем функцию check_bounds сразу после мутации
                offspring[i, gene_idx] = np.clip(offspring[i, gene_idx], param_ranges[gene_idx][0], param_ranges[gene_idx][1])

    return offspring




# Оптимизация генетическим алгоритмом genalg
class GeneticAlgorithmOptimizer:
    def __init__(self, param_ranges, population_size, offspring_ratio, mutation_rate, mutation_strength, mutation_percent_genes,
                 mutation_by_replacement, elite_fraction, initialization_method, selection_percentage, early_stopping_patience, generations=2):
        self.param_ranges = param_ranges
        self.population_size = population_size
        self.offspring_ratio = offspring_ratio
        self.mutation_rate = mutation_rate
        self.mutation_strength = mutation_strength
        self.mutation_percent_genes = mutation_percent_genes
        self.mutation_by_replacement = mutation_by_replacement
        self.elite_fraction = elite_fraction
        self.initialization_method = initialization_method
        self.selection_percentage = selection_percentage
        self.early_stopping_patience = early_stopping_patience
        self.generations = generations
    
    def optimize(self):
        # Инициализация популяции
        population = initialize_population(self.population_size, self.param_ranges)
        # print(f"Инициализация популяции: {np.array(population).shape}")
        
        # Оценка начальной популяции
        fitness_values = np.array([cached_objective_function(tuple(ind)) for ind in population])
        fitness_values = np.squeeze(fitness_values) 
        # print(f"Оценка начальной популяции, первая особь: {fitness_values[:1]}")
        
        best_solution = None
        best_fitness = float('inf')
        no_improvement_count = 0

        global_start_time = time.time()

        for generation in range(self.generations):
            print(f"\nПоколение {generation + 1}")
            
            # Селекция лучших индивидов с элитизмом
            selected_population, selected_fitness = select_top_individuals_with_elitism(
            np.squeeze(population), np.squeeze(fitness_values), 
            self.selection_percentage, elite_count=int(self.elite_fraction * self.population_size)
            )
            
            # Контроль индексов и значений
            # print(f"Индексы элитных особей: {selected_population[:10]}")
            # print(f"Размер выбранной популяции: {np.array(selected_population).shape}, лучший фитнес: {selected_fitness[:1]}")
            
            # Создание потомков через скрещивание
            num_offspring = int(len(selected_population) * self.offspring_ratio)
            offspring = generate_offspring(selected_population, num_offspring)
            # print(f"Создано потомков: {np.array(offspring).shape}")
            
            # Применение мутации к потомкам
            offspring = mutate(offspring, self.mutation_rate, self.mutation_strength, self.mutation_percent_genes,
                               self.mutation_by_replacement, self.param_ranges)
            
            # Применение функции check_bounds ко всем потомкам
            offspring = [check_bounds(ind, self.param_ranges) for ind in offspring]
            # print(f"Проверка потомков после мутации: {offspring}")

            # Применяем check_bounds к selected_population
            selected_population = np.array([check_bounds(ind, self.param_ranges) for ind in selected_population])


            # Объединение потомков и выбранных индивидов
            combined_population = np.concatenate([selected_population, offspring])
            combined_population = np.squeeze(combined_population)

            # Применяем check_bounds ко всей популяции
            combined_population = np.array([check_bounds(ind, self.param_ranges) for ind in combined_population])

            # Проверка каждого индивида, что он в пределах допустимых границ
            # for ind in combined_population:
            #     if not np.all(np.logical_and(ind >= [p[0] for p in self.param_ranges], ind <= [p[1] for p in self.param_ranges])):
            #         print(f"Индивид вне допустимых границ: {ind}")
            #     else:
            #         print(f"Индивид в пределах: {ind}")

            
            # Оценка новой популяции с преобразованием numpy.ndarray в tuple
            combined_fitness = np.array([cached_objective_function(tuple(ind.flatten())) for ind in combined_population])
            combined_fitness = np.squeeze(combined_fitness)
            # print(f"Лучший фитнес в новом поколении: {min(combined_fitness)}")

            # Селекция лучших индивидов для следующего поколения
            final_population, final_fitness = select_top_individuals_with_elitism(
                combined_population, combined_fitness, self.population_size / len(combined_population),
                elite_count=int(self.elite_fraction * self.population_size)
            )

            population = final_population
            fitness_values = final_fitness

            # Определение лучшего решения
            current_best_fitness = np.min(final_fitness)

            current_best_solution = np.squeeze(final_population[np.argmin(final_fitness)])


            if current_best_fitness < best_fitness:
                best_fitness = current_best_fitness
                best_solution = current_best_solution
                no_improvement_count = 0
            else:
                no_improvement_count += 1

            # Выводим лучший результат и параметры для текущего поколения
            print(f"Поколение {generation + 1}: Лучший MSE: {best_fitness}")

            
            # Раннее завершение, если нет улучшений
            if no_improvement_count >= self.early_stopping_patience:
                break

        elapsed_time = time.time() - global_start_time
        return best_solution, best_fitness, generation + 1, elapsed_time






# Генерация случайных гиперпараметров
def generate_random_hyperparameters():
    hyperparameters = {
        "population_size": random.randint(10, 100),
        "offspring_ratio": random.uniform(1.5, 3.0),
        "mutation_rate": random.uniform(0.1, 0.5),
        "mutation_strength": random.uniform(0.1, 0.5),
        "mutation_percent_genes": random.uniform(0.1, 0.2),
        "mutation_by_replacement": random.choice([True]),
        "elite_fraction": random.uniform(0.05, 0.2),
        "initialization_method": random.choice(['random', 'lhs'])
    }
    return hyperparameters

# Количество внешних и внутренних прогонов
num_outer_runs = 4  # Число внешних циклов для тестирования разных гиперпараметров
num_inner_runs = 5   # Число внутренних циклов для усреднения результатов одного набора гиперпараметров
summary_results = []  # Список для хранения итоговых результатов
csv_filename = 'cust_houses.csv'  # Имя файла для сохранения результатов

# Внешний цикл для тестирования разных гиперпараметров
for outer_run in range(num_outer_runs):
    print(f"\n=== Внешний прогон {outer_run + 1} ===\n")
    
    # Генерация случайных гиперпараметров
    hyperparams = generate_random_hyperparameters()
    # print(f"Сгенерированные гиперпараметры для внешнего прогона {outer_run + 1}: {hyperparams}")
    
    results = []  # Список для хранения результатов одного внешнего цикла

    # Внутренний цикл для усреднения результатов одного набора гиперпараметров
    for inner_run in range(num_inner_runs):
        # Инициализация оптимизатора генетического алгоритма
        optimizer = GeneticAlgorithmOptimizer(
            param_ranges=[
                (50, 2000),    # n_estimators
                (1, 100),      # max_depth
                (2, 1000),     # num_leaves
                [0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],   # learning_rate
                (10, 1000),    # max_bin
                [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]     # colsample_bytree
            ],
            **hyperparams,  # Передаем гиперпараметры
            generations=30,  # Количество поколений для генетического алгоритма
            selection_percentage=0.5,
            early_stopping_patience=10
        )

        # Оптимизация для данного набора гиперпараметров
        best_solution, best_fitness, best_generation, best_generation_time = optimizer.optimize()

        # Сохранение результатов внутреннего прогона
        run_data = {
            'Best MSE': best_fitness,
            'Best Generation': best_generation,
            'Time to Best Generation': best_generation_time,
            'Population Size': hyperparams["population_size"],
            'Mutation Rate': hyperparams["mutation_rate"],
            'Offspring Ratio': hyperparams["offspring_ratio"],  # Сохраняем правильно!
            'Mutation Strength': hyperparams["mutation_strength"],
            'Mutation Percent Genes': hyperparams["mutation_percent_genes"],
            'Elite Fraction': hyperparams["elite_fraction"]
        }
        results.append(run_data)

    # Обработка результатов внутреннего цикла
    df_results = pd.DataFrame(results)
    median_fitness = df_results['Best MSE'].median()
    mode_iteration = df_results['Best Generation'].mode()[0]
    median_time_to_best_gen = df_results['Time to Best Generation'].median()

    # Подготовка строки для сохранения в CSV
    summary_row = {
        'Median MSE': median_fitness,
        'Mode Best Generation': mode_iteration,
        'Median Time to Best Generation': median_time_to_best_gen,
        'Population Size': hyperparams["population_size"],
        'Mutation Rate': hyperparams["mutation_rate"],
        'Offspring Ratio': hyperparams["offspring_ratio"],
        'Mutation Strength': hyperparams["mutation_strength"],
        'Mutation Percent Genes': hyperparams["mutation_percent_genes"],
        'Elite Fraction': hyperparams["elite_fraction"]
    }

    summary_results.append(summary_row)

    # Добавляем строку в CSV-файл после каждого внешнего прогона
    df_summary = pd.DataFrame([summary_row])
    df_summary.to_csv(csv_filename, mode='a', header=not pd.io.common.file_exists(csv_filename), index=False)

    # Очистка памяти после каждого внешнего цикла
    gc.collect()

# Вывод итоговых результатов после всех внешних прогонов
df_summary = pd.DataFrame(summary_results)
print("\nИтоговая таблица с медианными значениями и гиперпараметрами:")
print(df_summary)
# Out:
# === Внешний прогон 1 ===
#
#
# Поколение 1
# Поколение 1: Лучший MSE: 513014.9757720476
#
# Поколение 2
# Поколение 2: Лучший MSE: 512189.58572587435
#
# Поколение 3
# Поколение 3: Лучший MSE: 512189.58572587435
#
# Поколение 4
# Поколение 4: Лучший MSE: 512189.58572587435
#
# Поколение 5
# Поколение 5: Лучший MSE: 510053.902410762
#
# Поколение 6
# Поколение 6: Лучший MSE: 510053.902410762
#
# Поколение 7
# Поколение 7: Лучший MSE: 510053.902410762
#
# Поколение 8
# Поколение 8: Лучший MSE: 510053.902410762
#
# Поколение 9
# Поколение 9: Лучший MSE: 510053.902410762
#
# Поколение 10
# Поколение 10: Лучший MSE: 510053.902410762
#
# Поколение 11
# Поколение 11: Лучший MSE: 509176.1073024581
#
# Поколение 12
# Поколение 12: Лучший MSE: 509176.1073024581
#
# Поколение 13
# Поколение 13: Лучший MSE: 509176.1073024581
#
# Поколение 14
# Поколение 14: Лучший MSE: 508294.48995135725
#
# Поколение 15
# Поколение 15: Лучший MSE: 508294.48995135725
#
# Поколение 16
# Поколение 16: Лучший MSE: 508294.48995135725
#
# Поколение 17
# Поколение 17: Лучший MSE: 508294.48995135725
#
# Поколение 18
# Поколение 18: Лучший MSE: 508294.48995135725
#
# Поколение 19
# Поколение 19: Лучший MSE: 508046.9568091021
#
# Поколение 20
# Поколение 20: Лучший MSE: 508046.9568091021
#
# Поколение 21
# Поколение 21: Лучший MSE: 508046.9568091021
#
# Поколение 22
# Поколение 22: Лучший MSE: 508046.9568091021
#
# Поколение 23
# Поколение 23: Лучший MSE: 508046.9568091021
#
# Поколение 24
# Поколение 24: Лучший MSE: 507979.0015751386
#
# Поколение 25
# Поколение 25: Лучший MSE: 507979.0015751386
#
# Поколение 26
# Поколение 26: Лучший MSE: 507978.985963061
#
# Поколение 27
# Поколение 27: Лучший MSE: 507978.985963061
#
# Поколение 28
# Поколение 28: Лучший MSE: 507978.985963061
#
# Поколение 29
# Поколение 29: Лучший MSE: 507978.985963061
#
# Поколение 30
# Поколение 30: Лучший MSE: 507978.98592507356
#
# Поколение 1
# Поколение 1: Лучший MSE: 513167.3265338287
#
# Поколение 2
# Поколение 2: Лучший MSE: 513167.3265338287
#
# Поколение 3
# Поколение 3: Лучший MSE: 512976.6983386452
#
# Поколение 4
# Поколение 4: Лучший MSE: 512054.7274911625
#
# Поколение 5
# Поколение 5: Лучший MSE: 511837.023626538
#
# Поколение 6
# Поколение 6: Лучший MSE: 511837.023626538
#
# Поколение 7
# Поколение 7: Лучший MSE: 510401.0306689455
#
# Поколение 8
# Поколение 8: Лучший MSE: 510401.0306689455
#
# Поколение 9
# Поколение 9: Лучший MSE: 510401.0306689455
#
# Поколение 10
# Поколение 10: Лучший MSE: 510401.0306689455
#
# Поколение 11
# Поколение 11: Лучший MSE: 510401.0306689455
#
# Поколение 12
# Поколение 12: Лучший MSE: 510401.0306689455
#
# Поколение 13
# Поколение 13: Лучший MSE: 510401.0306689455
#
# Поколение 14
# Поколение 14: Лучший MSE: 510401.0306689455
#
# Поколение 15
# Поколение 15: Лучший MSE: 510401.0306689455
#
# Поколение 16
# Поколение 16: Лучший MSE: 510401.0306689455
#
# Поколение 17
# Поколение 17: Лучший MSE: 510401.0306689455
#
# Поколение 1
# Поколение 1: Лучший MSE: 515677.3740530344
#
# Поколение 2
# Поколение 2: Лучший MSE: 514293.57302561525
#
# Поколение 3
# Поколение 3: Лучший MSE: 512080.95372885355
#
# Поколение 4
# Поколение 4: Лучший MSE: 512080.95372885355
#
# Поколение 5
# Поколение 5: Лучший MSE: 512080.95372885355
#
# Поколение 6
# Поколение 6: Лучший MSE: 511970.5656759238
#
# Поколение 7
# Поколение 7: Лучший MSE: 511970.5656759238
#
# Поколение 8
# Поколение 8: Лучший MSE: 511970.5656759238
#
# Поколение 9
# Поколение 9: Лучший MSE: 511923.30846566707
#
# Поколение 10
# Поколение 10: Лучший MSE: 511923.30846566707
#
# Поколение 11
# Поколение 11: Лучший MSE: 511361.15867019474
#
# Поколение 12
# Поколение 12: Лучший MSE: 511361.15867019474
#
# Поколение 13
# Поколение 13: Лучший MSE: 511361.15867019474
#
# Поколение 14
# Поколение 14: Лучший MSE: 511361.15867019474
#
# Поколение 15
# Поколение 15: Лучший MSE: 511361.15867019474
#
# Поколение 16
# Поколение 16: Лучший MSE: 511361.15867019474
#
# Поколение 17
# Поколение 17: Лучший MSE: 510389.0816656958
#
# Поколение 18
# Поколение 18: Лучший MSE: 510389.0816656958
#
# Поколение 19
# Поколение 19: Лучший MSE: 510389.0816656958
#
# Поколение 20
# Поколение 20: Лучший MSE: 510389.0816656958
#
# Поколение 21
# Поколение 21: Лучший MSE: 510389.0816656958
#
# Поколение 22
# Поколение 22: Лучший MSE: 510389.0816656958
#
# Поколение 23
# Поколение 23: Лучший MSE: 510389.0816656958
#
# Поколение 24
# Поколение 24: Лучший MSE: 510389.0816656958
#
# Поколение 25
# Поколение 25: Лучший MSE: 510389.0816656958
#
# Поколение 26
# Поколение 26: Лучший MSE: 510389.0816559557
#
# Поколение 27
# Поколение 27: Лучший MSE: 510389.0816559557
#
# Поколение 28
# Поколение 28: Лучший MSE: 510389.08164919465
#
# Поколение 29
# Поколение 29: Лучший MSE: 510389.08164919465
#
# Поколение 30
# Поколение 30: Лучший MSE: 510389.0816469656
#
# Поколение 1
# Поколение 1: Лучший MSE: 518491.65202066215
#
# Поколение 2
# Поколение 2: Лучший MSE: 515287.9548561995
#
# Поколение 3
# Поколение 3: Лучший MSE: 515287.9548561995
#
# Поколение 4
# Поколение 4: Лучший MSE: 513764.969211427
#
# Поколение 5
# Поколение 5: Лучший MSE: 512786.6418548539
#
# Поколение 6
# Поколение 6: Лучший MSE: 512786.6418548539
#
# Поколение 7
# Поколение 7: Лучший MSE: 512786.6418548539
#
# Поколение 8
# Поколение 8: Лучший MSE: 512786.6418548539
#
# Поколение 9
# Поколение 9: Лучший MSE: 512786.6418548539
#
# Поколение 10
# Поколение 10: Лучший MSE: 512606.62222262815
#
# Поколение 11
# Поколение 11: Лучший MSE: 511773.053407643
#
# Поколение 12
# Поколение 12: Лучший MSE: 511773.053407643
#
# Поколение 13
# Поколение 13: Лучший MSE: 511773.053407643
#
# Поколение 14
# Поколение 14: Лучший MSE: 511773.053407643
#
# Поколение 15
# Поколение 15: Лучший MSE: 511773.053407643
#
# Поколение 16
# Поколение 16: Лучший MSE: 511773.053407643
#
# Поколение 17
# Поколение 17: Лучший MSE: 511773.053407643
#
# Поколение 18
# Поколение 18: Лучший MSE: 511773.053407643
#
# Поколение 19
# Поколение 19: Лучший MSE: 511770.2071167046
#
# Поколение 20
# Поколение 20: Лучший MSE: 511770.2071167046
#
# Поколение 21
# Поколение 21: Лучший MSE: 511770.2071167046
#
# Поколение 22
# Поколение 22: Лучший MSE: 511770.2071167046
#
# Поколение 23
# Поколение 23: Лучший MSE: 511357.6742022773
#
# Поколение 24
# Поколение 24: Лучший MSE: 511357.6742022773
#
# Поколение 25
# Поколение 25: Лучший MSE: 511357.6742022773
#
# Поколение 26
# Поколение 26: Лучший MSE: 511357.6742022773
#
# Поколение 27
# Поколение 27: Лучший MSE: 511357.6742022773
#
# Поколение 28
# Поколение 28: Лучший MSE: 511357.6742022773
#
# Поколение 29
# Поколение 29: Лучший MSE: 511357.6742022773
#
# Поколение 30
# Поколение 30: Лучший MSE: 511357.6742022773
#
# Поколение 1
# Поколение 1: Лучший MSE: 514208.57537699677
#
# Поколение 2
# Поколение 2: Лучший MSE: 512460.85457933246
#
# Поколение 3
# Поколение 3: Лучший MSE: 511323.9866312722
#
# Поколение 4
# Поколение 4: Лучший MSE: 509526.67344276956
#
# Поколение 5
# Поколение 5: Лучший MSE: 509022.12588684907
#
# Поколение 6
# Поколение 6: Лучший MSE: 508800.8630564984
#
# Поколение 7
# Поколение 7: Лучший MSE: 508592.8115129536
#
# Поколение 8
# Поколение 8: Лучший MSE: 508592.8115129536
#
# Поколение 9
# Поколение 9: Лучший MSE: 508569.7092809028
#
# Поколение 10
# Поколение 10: Лучший MSE: 508431.19537238864
#
# Поколение 11
# Поколение 11: Лучший MSE: 508265.6627699931
#
# Поколение 12
# Поколение 12: Лучший MSE: 508265.6627699931
#
# Поколение 13
# Поколение 13: Лучший MSE: 508265.6627699931
#
# Поколение 14
# Поколение 14: Лучший MSE: 508265.6188817744
#
# Поколение 15
# Поколение 15: Лучший MSE: 508234.5204837392
#
# Поколение 16
# Поколение 16: Лучший MSE: 508001.01958922687
#
# Поколение 17
# Поколение 17: Лучший MSE: 508001.0186043892
#
# Поколение 18
# Поколение 18: Лучший MSE: 508001.0186043892
#
# Поколение 19
# Поколение 19: Лучший MSE: 508001.0186043892
#
# Поколение 20
# Поколение 20: Лучший MSE: 508001.0186043892
#
# Поколение 21
# Поколение 21: Лучший MSE: 508001.0186043892
#
# Поколение 22
# Поколение 22: Лучший MSE: 508001.0186043892
#
# Поколение 23
# Поколение 23: Лучший MSE: 508001.0186043892
#
# Поколение 24
# Поколение 24: Лучший MSE: 508001.01859591383
#
# Поколение 25
# Поколение 25: Лучший MSE: 508001.0185944592
#
# Поколение 26
# Поколение 26: Лучший MSE: 508001.0185916655
#
# Поколение 27
# Поколение 27: Лучший MSE: 508001.01858954254
#
# Поколение 28
# Поколение 28: Лучший MSE: 508001.0185846362
#
# Поколение 29
# Поколение 29: Лучший MSE: 508001.0185846362
#
# Поколение 30
# Поколение 30: Лучший MSE: 508001.01858223905
#
# === Внешний прогон 2 ===
#
#
# Поколение 1
# Поколение 1: Лучший MSE: 513184.6251188778
#
# Поколение 2
# Поколение 2: Лучший MSE: 512672.55064409156
#
# Поколение 3
# Поколение 3: Лучший MSE: 512672.55064409156
#
# Поколение 4
# Поколение 4: Лучший MSE: 512672.55064409156
#
# Поколение 5
# Поколение 5: Лучший MSE: 512672.55064409156
#
# Поколение 6
# Поколение 6: Лучший MSE: 512672.55064409156
#
# Поколение 7
# Поколение 7: Лучший MSE: 511958.2927005419
#
# Поколение 8
# Поколение 8: Лучший MSE: 511958.2927005419
#
# Поколение 9
# Поколение 9: Лучший MSE: 511958.2927005419
#
# Поколение 10
# Поколение 10: Лучший MSE: 509054.9615918719
#
# Поколение 11
# Поколение 11: Лучший MSE: 509054.9615918719
#
# Поколение 12
# Поколение 12: Лучший MSE: 509054.9615918719
#
# Поколение 13
# Поколение 13: Лучший MSE: 509054.9615918719
#
# Поколение 14
# Поколение 14: Лучший MSE: 509054.9615918719
#
# Поколение 15
# Поколение 15: Лучший MSE: 509054.9615918719
#
# Поколение 16
# Поколение 16: Лучший MSE: 509054.9615918719
#
# Поколение 17
# Поколение 17: Лучший MSE: 509054.9615918719
#
# Поколение 18
# Поколение 18: Лучший MSE: 509007.3840303404
#
# Поколение 19
# Поколение 19: Лучший MSE: 509007.3840303404
#
# Поколение 20
# Поколение 20: Лучший MSE: 508917.09866374166
#
# Поколение 21
# Поколение 21: Лучший MSE: 508887.77655753685
#
# Поколение 22
# Поколение 22: Лучший MSE: 508805.6060834769
#
# Поколение 23
# Поколение 23: Лучший MSE: 508805.6060834769
#
# Поколение 24
# Поколение 24: Лучший MSE: 508805.6060834769
#
# Поколение 25
# Поколение 25: Лучший MSE: 508805.6060834769
#
# Поколение 26
# Поколение 26: Лучший MSE: 508805.6060834769
#
# Поколение 27
# Поколение 27: Лучший MSE: 508805.6060834769
#
# Поколение 28
# Поколение 28: Лучший MSE: 508805.6060834769
#
# Поколение 29
# Поколение 29: Лучший MSE: 508805.6060834769
#
# Поколение 30
# Поколение 30: Лучший MSE: 508805.6060834769
#
# Поколение 1
# Поколение 1: Лучший MSE: 517070.0627830101
#
# Поколение 2
# Поколение 2: Лучший MSE: 513426.403251115
#
# Поколение 3
# Поколение 3: Лучший MSE: 512987.42896785884
#
# Поколение 4
# Поколение 4: Лучший MSE: 511111.2959881427
#
# Поколение 5
# Поколение 5: Лучший MSE: 508976.94489263935
#
# Поколение 6
# Поколение 6: Лучший MSE: 508835.4272872748
#
# Поколение 7
# Поколение 7: Лучший MSE: 508553.2366936202
#
# Поколение 8
# Поколение 8: Лучший MSE: 508553.2366936202
#
# Поколение 9
# Поколение 9: Лучший MSE: 508070.43103113933
#
# Поколение 10
# Поколение 10: Лучший MSE: 508070.43103113933
#
# Поколение 11
# Поколение 11: Лучший MSE: 507872.72039473004
#
# Поколение 12
# Поколение 12: Лучший MSE: 507872.72039473004
#
# Поколение 13
# Поколение 13: Лучший MSE: 507724.92804240383
#
# Поколение 14
# Поколение 14: Лучший MSE: 507724.92804240383
#
# Поколение 15
# Поколение 15: Лучший MSE: 507724.92804240383
#
# Поколение 16
# Поколение 16: Лучший MSE: 507724.92804240383
#
# Поколение 17
# Поколение 17: Лучший MSE: 507421.23569798796
#
# Поколение 18
# Поколение 18: Лучший MSE: 507348.3036118885
#
# Поколение 19
# Поколение 19: Лучший MSE: 507348.3036118885
#
# Поколение 20
# Поколение 20: Лучший MSE: 507348.3036118885
#
# Поколение 21
# Поколение 21: Лучший MSE: 507348.3036118885
#
# Поколение 22
# Поколение 22: Лучший MSE: 507348.3036118885
#
# Поколение 23
# Поколение 23: Лучший MSE: 507348.3036118885
#
# Поколение 24
# Поколение 24: Лучший MSE: 507348.3036118885
#
# Поколение 25
# Поколение 25: Лучший MSE: 507348.3036118885
#
# Поколение 26
# Поколение 26: Лучший MSE: 507348.3036118885
#
# Поколение 27
# Поколение 27: Лучший MSE: 507348.3036118885
#
# Поколение 28
# Поколение 28: Лучший MSE: 507348.3036118885
#
# Поколение 1
# Поколение 1: Лучший MSE: 512637.89791015285
#
# Поколение 2
# Поколение 2: Лучший MSE: 510970.7314284237
#
# Поколение 3
# Поколение 3: Лучший MSE: 510453.710938901
#
# Поколение 4
# Поколение 4: Лучший MSE: 509380.2680318148
#
# Поколение 5
# Поколение 5: Лучший MSE: 509380.2680318148
#
# Поколение 6
# Поколение 6: Лучший MSE: 509380.2680318148
#
# Поколение 7
# Поколение 7: Лучший MSE: 508754.96886419854
#
# Поколение 8
# Поколение 8: Лучший MSE: 508754.96886419854
#
# Поколение 9
# Поколение 9: Лучший MSE: 508754.96886419854
#
# Поколение 10
# Поколение 10: Лучший MSE: 508754.96886419854
#
# Поколение 11
# Поколение 11: Лучший MSE: 508754.96886419854
#
# Поколение 12
# Поколение 12: Лучший MSE: 508754.96886419854
#
# Поколение 13
# Поколение 13: Лучший MSE: 508754.96886419854
#
# Поколение 14
# Поколение 14: Лучший MSE: 508754.96886419854
#
# Поколение 15
# Поколение 15: Лучший MSE: 508754.96886419854
#
# Поколение 16
# Поколение 16: Лучший MSE: 508754.96886419854
#
# Поколение 17
# Поколение 17: Лучший MSE: 508754.96886419854
#
# Поколение 1
# Поколение 1: Лучший MSE: 513472.6360488888
#
# Поколение 2
# Поколение 2: Лучший MSE: 513472.6360488888
#
# Поколение 3
# Поколение 3: Лучший MSE: 512175.5517172033
#
# Поколение 4
# Поколение 4: Лучший MSE: 512175.5517172033
#
# Поколение 5
# Поколение 5: Лучший MSE: 510106.54063830205
#
# Поколение 6
# Поколение 6: Лучший MSE: 510106.54063830205
#
# Поколение 7
# Поколение 7: Лучший MSE: 506809.29639331857
#
# Поколение 8
# Поколение 8: Лучший MSE: 506809.29639331857
#
# Поколение 9
# Поколение 9: Лучший MSE: 506809.29639331857
#
# Поколение 10
# Поколение 10: Лучший MSE: 506809.29639331857
#
# Поколение 11
# Поколение 11: Лучший MSE: 506809.29639331857
#
# Поколение 12
# Поколение 12: Лучший MSE: 506809.29639331857
#
# Поколение 13
# Поколение 13: Лучший MSE: 506809.29639331857
#
# Поколение 14
# Поколение 14: Лучший MSE: 506809.29639331857
#
# Поколение 15
# Поколение 15: Лучший MSE: 506809.29639331857
#
# Поколение 16
# Поколение 16: Лучший MSE: 506809.29639331857
#
# Поколение 17
# Поколение 17: Лучший MSE: 506809.29639331857
#
# Поколение 1
# Поколение 1: Лучший MSE: 512748.15458434285
#
# Поколение 2
# Поколение 2: Лучший MSE: 510010.420487545
#
# Поколение 3
# Поколение 3: Лучший MSE: 510010.420487545
#
# Поколение 4
# Поколение 4: Лучший MSE: 510010.420487545
#
# Поколение 5
# Поколение 5: Лучший MSE: 510010.420487545
#
# Поколение 6
# Поколение 6: Лучший MSE: 510010.420487545
#
# Поколение 7
# Поколение 7: Лучший MSE: 510010.420487545
#
# Поколение 8
# Поколение 8: Лучший MSE: 510010.420487545
#
# Поколение 9
# Поколение 9: Лучший MSE: 510010.420487545
#
# Поколение 10
# Поколение 10: Лучший MSE: 510010.420487545
#
# Поколение 11
# Поколение 11: Лучший MSE: 508953.71080980543
#
# Поколение 12
# Поколение 12: Лучший MSE: 508953.71080980543
#
# Поколение 13
# Поколение 13: Лучший MSE: 508953.71080980543
#
# Поколение 14
# Поколение 14: Лучший MSE: 508185.7363390266
#
# Поколение 15
# Поколение 15: Лучший MSE: 508185.7363390266
#
# Поколение 16
# Поколение 16: Лучший MSE: 508185.7363390266
#
# Поколение 17
# Поколение 17: Лучший MSE: 508185.7363390266
#
# Поколение 18
# Поколение 18: Лучший MSE: 508185.7363390266
#
# Поколение 19
# Поколение 19: Лучший MSE: 508185.7363390266
#
# Поколение 20
# Поколение 20: Лучший MSE: 508185.7363390266
#
# Поколение 21
# Поколение 21: Лучший MSE: 508185.7363390266
#
# Поколение 22
# Поколение 22: Лучший MSE: 508185.7363390266
#
# Поколение 23
# Поколение 23: Лучший MSE: 508185.7363390266
#
# Поколение 24
# Поколение 24: Лучший MSE: 508185.7363390266
#
# === Внешний прогон 3 ===
#
#
# Поколение 1
# Поколение 1: Лучший MSE: 512482.5459589642
#
# Поколение 2
# Поколение 2: Лучший MSE: 512482.5459589642
#
# Поколение 3
# Поколение 3: Лучший MSE: 512482.5459589642
#
# Поколение 4
# Поколение 4: Лучший MSE: 512482.5459589642
#
# Поколение 5
# Поколение 5: Лучший MSE: 512234.42447689985
#
# Поколение 6
# Поколение 6: Лучший MSE: 509368.7457821061
#
# Поколение 7
# Поколение 7: Лучший MSE: 509368.7457821061
#
# Поколение 8
# Поколение 8: Лучший MSE: 509368.7457821061
#
# Поколение 9
# Поколение 9: Лучший MSE: 509065.4621208229
#
# Поколение 10
# Поколение 10: Лучший MSE: 508878.16361498757
#
# Поколение 11
# Поколение 11: Лучший MSE: 508878.16361498757
#
# Поколение 12
# Поколение 12: Лучший MSE: 508878.16361498757
#
# Поколение 13
# Поколение 13: Лучший MSE: 507108.45907804096
#
# Поколение 14
# Поколение 14: Лучший MSE: 507108.45907804096
#
# Поколение 15
# Поколение 15: Лучший MSE: 507108.45907804096
#
# Поколение 16
# Поколение 16: Лучший MSE: 507108.45907804096
#
# Поколение 17
# Поколение 17: Лучший MSE: 507108.45907804096
#
# Поколение 18
# Поколение 18: Лучший MSE: 507108.45907804096
#
# Поколение 19
# Поколение 19: Лучший MSE: 507108.45907804096
#
# Поколение 20
# Поколение 20: Лучший MSE: 507108.45907804096
#
# Поколение 21
# Поколение 21: Лучший MSE: 507108.45907804096
#
# Поколение 22
# Поколение 22: Лучший MSE: 507108.45907804096
#
# Поколение 23
# Поколение 23: Лучший MSE: 507108.45907804096
#
# Поколение 1
# Поколение 1: Лучший MSE: 513060.4131541091
#
# Поколение 2
# Поколение 2: Лучший MSE: 513060.4131541091
#
# Поколение 3
# Поколение 3: Лучший MSE: 510909.3542802301
#
# Поколение 4
# Поколение 4: Лучший MSE: 508124.4725105799
#
# Поколение 5
# Поколение 5: Лучший MSE: 508124.4725105799
#
# Поколение 6
# Поколение 6: Лучший MSE: 508124.4725105799
#
# Поколение 7
# Поколение 7: Лучший MSE: 508124.4725105799
#
# Поколение 8
# Поколение 8: Лучший MSE: 508124.4725105799
#
# Поколение 9
# Поколение 9: Лучший MSE: 507843.7685788703
#
# Поколение 10
# Поколение 10: Лучший MSE: 507843.7685788703
#
# Поколение 11
# Поколение 11: Лучший MSE: 507843.7685788703
#
# Поколение 12
# Поколение 12: Лучший MSE: 507843.7685788703
#
# Поколение 13
# Поколение 13: Лучший MSE: 507843.7685788703
#
# Поколение 14
# Поколение 14: Лучший MSE: 507542.10071034956
#
# Поколение 15
# Поколение 15: Лучший MSE: 507542.10071034956
#
# Поколение 16
# Поколение 16: Лучший MSE: 507542.10071034956
#
# Поколение 17
# Поколение 17: Лучший MSE: 507542.09563153144
#
# Поколение 18
# Поколение 18: Лучший MSE: 507542.09563153144
#
# Поколение 19
# Поколение 19: Лучший MSE: 507542.09563153144
#
# Поколение 20
# Поколение 20: Лучший MSE: 507542.09563153144
#
# Поколение 21
# Поколение 21: Лучший MSE: 507542.09563153144
#
# Поколение 22
# Поколение 22: Лучший MSE: 507542.09563153144
#
# Поколение 23
# Поколение 23: Лучший MSE: 507542.09563153144
#
# Поколение 24
# Поколение 24: Лучший MSE: 507542.09563153144
#
# Поколение 25
# Поколение 25: Лучший MSE: 507542.09563153144
#
# Поколение 26
# Поколение 26: Лучший MSE: 507542.0956243622
#
# Поколение 27
# Поколение 27: Лучший MSE: 507542.0956243622
#
# Поколение 28
# Поколение 28: Лучший MSE: 507542.0956212392
#
# Поколение 29
# Поколение 29: Лучший MSE: 507542.09561528737
#
# Поколение 30
# Поколение 30: Лучший MSE: 507542.09561528737
#
# Поколение 1
# Поколение 1: Лучший MSE: 513919.22837012034
#
# Поколение 2
# Поколение 2: Лучший MSE: 511527.0485160942
#
# Поколение 3
# Поколение 3: Лучший MSE: 511527.0485160942
#
# Поколение 4
# Поколение 4: Лучший MSE: 511510.05024161114
#
# Поколение 5
# Поколение 5: Лучший MSE: 511510.05024161114
#
# Поколение 6
# Поколение 6: Лучший MSE: 511510.05024161114
#
# Поколение 7
# Поколение 7: Лучший MSE: 509916.33385610953
#
# Поколение 8
# Поколение 8: Лучший MSE: 509916.33385610953
#
# Поколение 9
# Поколение 9: Лучший MSE: 509916.33385610953
#
# Поколение 10
# Поколение 10: Лучший MSE: 509873.02625589404
#
# Поколение 11
# Поколение 11: Лучший MSE: 509832.39863924385
#
# Поколение 12
# Поколение 12: Лучший MSE: 509645.65633093525
#
# Поколение 13
# Поколение 13: Лучший MSE: 509645.65633093525
#
# Поколение 14
# Поколение 14: Лучший MSE: 509645.65633093525
#
# Поколение 15
# Поколение 15: Лучший MSE: 509645.6449053295
#
# Поколение 16
# Поколение 16: Лучший MSE: 509645.64376941015
#
# Поколение 17
# Поколение 17: Лучший MSE: 509645.64376941015
#
# Поколение 18
# Поколение 18: Лучший MSE: 509645.64376941015
#
# Поколение 19
# Поколение 19: Лучший MSE: 509645.6437678493
#
# Поколение 20
# Поколение 20: Лучший MSE: 509645.6437663813
#
# Поколение 21
# Поколение 21: Лучший MSE: 509645.6437663813
#
# Поколение 22
# Поколение 22: Лучший MSE: 509645.6437605359
#
# Поколение 23
# Поколение 23: Лучший MSE: 509645.64375800855
#
# Поколение 24
# Поколение 24: Лучший MSE: 509645.64375800855
#
# Поколение 25
# Поколение 25: Лучший MSE: 509645.64375800855
#
# Поколение 26
# Поколение 26: Лучший MSE: 509645.64375800855
#
# Поколение 27
# Поколение 27: Лучший MSE: 509645.6437556909
#
# Поколение 28
# Поколение 28: Лучший MSE: 509645.64375525364
#
# Поколение 29
# Поколение 29: Лучший MSE: 509645.6437551252
#
# Поколение 30
# Поколение 30: Лучший MSE: 509645.64375496394
#
# Поколение 1
# Поколение 1: Лучший MSE: 514503.3795568533
#
# Поколение 2
# Поколение 2: Лучший MSE: 509597.25939440384
#
# Поколение 3
# Поколение 3: Лучший MSE: 509022.40419731155
#
# Поколение 4
# Поколение 4: Лучший MSE: 509022.40419731155
#
# Поколение 5
# Поколение 5: Лучший MSE: 509022.40419731155
#
# Поколение 6
# Поколение 6: Лучший MSE: 508842.50138532784
#
# Поколение 7
# Поколение 7: Лучший MSE: 508842.50138532784
#
# Поколение 8
# Поколение 8: Лучший MSE: 508842.50138532784
#
# Поколение 9
# Поколение 9: Лучший MSE: 508842.50138532784
#
# Поколение 10
# Поколение 10: Лучший MSE: 508529.2386247451
#
# Поколение 11
# Поколение 11: Лучший MSE: 507509.96959548927
#
# Поколение 12
# Поколение 12: Лучший MSE: 507509.96959548927
#
# Поколение 13
# Поколение 13: Лучший MSE: 507509.96959548927
#
# Поколение 14
# Поколение 14: Лучший MSE: 507509.96959548927
#
# Поколение 15
# Поколение 15: Лучший MSE: 507509.96959548927
#
# Поколение 16
# Поколение 16: Лучший MSE: 507509.96959548927
#
# Поколение 17
# Поколение 17: Лучший MSE: 507509.96959548927
#
# Поколение 18
# Поколение 18: Лучший MSE: 507509.96959548927
#
# Поколение 19
# Поколение 19: Лучший MSE: 507509.96959548927
#
# Поколение 20
# Поколение 20: Лучший MSE: 507509.96959548927
#
# Поколение 21
# Поколение 21: Лучший MSE: 507509.96959548927
#
# Поколение 1
# Поколение 1: Лучший MSE: 512278.5143398361
#
# Поколение 2
# Поколение 2: Лучший MSE: 512278.5143398361
#
# Поколение 3
# Поколение 3: Лучший MSE: 510025.5546033284
#
# Поколение 4
# Поколение 4: Лучший MSE: 508836.6365839313
#
# Поколение 5
# Поколение 5: Лучший MSE: 508254.19077789877
#
# Поколение 6
# Поколение 6: Лучший MSE: 508254.19077789877
#
# Поколение 7
# Поколение 7: Лучший MSE: 508169.5368442672
#
# Поколение 8
# Поколение 8: Лучший MSE: 508169.5231833244
#
# Поколение 9
# Поколение 9: Лучший MSE: 508169.5231833244
#
# Поколение 10
# Поколение 10: Лучший MSE: 508169.5204701926
#
# Поколение 11
# Поколение 11: Лучший MSE: 508169.50761684397
#
# Поколение 12
# Поколение 12: Лучший MSE: 508169.50761684397
#
# Поколение 13
# Поколение 13: Лучший MSE: 508169.50761684397
#
# Поколение 14
# Поколение 14: Лучший MSE: 508169.5076035095
#
# Поколение 15
# Поколение 15: Лучший MSE: 508169.5075584729
#
# Поколение 16
# Поколение 16: Лучший MSE: 508169.5075584729
#
# Поколение 17
# Поколение 17: Лучший MSE: 508169.5075584729
#
# Поколение 18
# Поколение 18: Лучший MSE: 508169.5075584729
#
# Поколение 19
# Поколение 19: Лучший MSE: 508169.5075570875
#
# Поколение 20
# Поколение 20: Лучший MSE: 508169.5075515604
#
# Поколение 21
# Поколение 21: Лучший MSE: 508169.5075514365
#
# Поколение 22
# Поколение 22: Лучший MSE: 508169.5075514365
#
# Поколение 23
# Поколение 23: Лучший MSE: 508169.5075514365
#
# Поколение 24
# Поколение 24: Лучший MSE: 508169.5075506391
#
# Поколение 25
# Поколение 25: Лучший MSE: 508169.5075506391
#
# Поколение 26
# Поколение 26: Лучший MSE: 508169.5075497679
#
# Поколение 27
# Поколение 27: Лучший MSE: 508169.5075497679
#
# Поколение 28
# Поколение 28: Лучший MSE: 508169.5075497679
#
# Поколение 29
# Поколение 29: Лучший MSE: 508169.5075488869
#
# Поколение 30
# Поколение 30: Лучший MSE: 508169.5075488869
#
# === Внешний прогон 4 ===
#
#
# Поколение 1
# Поколение 1: Лучший MSE: 512613.5463117468
#
# Поколение 2
# Поколение 2: Лучший MSE: 509993.96075029206
#
# Поколение 3
# Поколение 3: Лучший MSE: 507869.1619231103
#
# Поколение 4
# Поколение 4: Лучший MSE: 507869.1619231103
#
# Поколение 5
# Поколение 5: Лучший MSE: 507869.1619231103
#
# Поколение 6
# Поколение 6: Лучший MSE: 507869.1619231103
#
# Поколение 7
# Поколение 7: Лучший MSE: 507869.1619231103
#
# Поколение 8
# Поколение 8: Лучший MSE: 507869.1619231103
#
# Поколение 9
# Поколение 9: Лучший MSE: 507869.1619231103
#
# Поколение 10
# Поколение 10: Лучший MSE: 507575.2427245118
#
# Поколение 11
# Поколение 11: Лучший MSE: 507575.2427245118
#
# Поколение 12
# Поколение 12: Лучший MSE: 507575.2427245118
#
# Поколение 13
# Поколение 13: Лучший MSE: 507575.2427245118
#
# Поколение 14
# Поколение 14: Лучший MSE: 507575.2427245118
#
# Поколение 15
# Поколение 15: Лучший MSE: 507575.2427245118
#
# Поколение 16
# Поколение 16: Лучший MSE: 507575.2427245118
#
# Поколение 17
# Поколение 17: Лучший MSE: 507575.19150489365
#
# Поколение 18
# Поколение 18: Лучший MSE: 507575.19150489365
#
# Поколение 19
# Поколение 19: Лучший MSE: 507575.19150489365
#
# Поколение 20
# Поколение 20: Лучший MSE: 507575.19150489365
#
# Поколение 21
# Поколение 21: Лучший MSE: 507575.1859320127
#
# Поколение 22
# Поколение 22: Лучший MSE: 507575.1832659792
#
# Поколение 23
# Поколение 23: Лучший MSE: 507575.1832659792
#
# Поколение 24
# Поколение 24: Лучший MSE: 507575.1832659792
#
# Поколение 25
# Поколение 25: Лучший MSE: 507575.1832659792
#
# Поколение 26
# Поколение 26: Лучший MSE: 507575.1832659792
#
# Поколение 27
# Поколение 27: Лучший MSE: 507575.1832659792
#
# Поколение 28
# Поколение 28: Лучший MSE: 507575.1832659792
#
# Поколение 29
# Поколение 29: Лучший MSE: 507575.18326488143
#
# Поколение 30
# Поколение 30: Лучший MSE: 507575.18326488143
#
# Поколение 1
# Поколение 1: Лучший MSE: 513859.80829993775
#
# Поколение 2
# Поколение 2: Лучший MSE: 513065.18282804266
#
# Поколение 3
# Поколение 3: Лучший MSE: 512636.08209258737
#
# Поколение 4
# Поколение 4: Лучший MSE: 509409.93096870504
#
# Поколение 5
# Поколение 5: Лучший MSE: 509043.3516526783
#
# Поколение 6
# Поколение 6: Лучший MSE: 508091.55639091344
#
# Поколение 7
# Поколение 7: Лучший MSE: 508091.55639091344
#
# Поколение 8
# Поколение 8: Лучший MSE: 506767.7697009335
#
# Поколение 9
# Поколение 9: Лучший MSE: 506767.7697009335
#
# Поколение 10
# Поколение 10: Лучший MSE: 506767.7697009335
#
# Поколение 11
# Поколение 11: Лучший MSE: 506767.7697009335
#
# Поколение 12
# Поколение 12: Лучший MSE: 506767.7697009335
#
# Поколение 13
# Поколение 13: Лучший MSE: 506767.7697009335
#
# Поколение 14
# Поколение 14: Лучший MSE: 506767.7697009335
#
# Поколение 15
# Поколение 15: Лучший MSE: 506767.7697009335
#
# Поколение 16
# Поколение 16: Лучший MSE: 506767.7697009335
#
# Поколение 17
# Поколение 17: Лучший MSE: 506767.7697009335
#
# Поколение 18
# Поколение 18: Лучший MSE: 506767.7697009335
#
# Поколение 1
# Поколение 1: Лучший MSE: 512954.3317356615
#
# Поколение 2
# Поколение 2: Лучший MSE: 511063.9016994904
#
# Поколение 3
# Поколение 3: Лучший MSE: 509172.48058522405
#
# Поколение 4
# Поколение 4: Лучший MSE: 509172.48058522405
#
# Поколение 5
# Поколение 5: Лучший MSE: 508943.18894068844
#
# Поколение 6
# Поколение 6: Лучший MSE: 508928.8933520194
#
# Поколение 7
# Поколение 7: Лучший MSE: 508928.8933520194
#
# Поколение 8
# Поколение 8: Лучший MSE: 507985.7439391866
#
# Поколение 9
# Поколение 9: Лучший MSE: 506896.1076343746
#
# Поколение 10
# Поколение 10: Лучший MSE: 506896.1076343746
#
# Поколение 11
# Поколение 11: Лучший MSE: 506463.27240144537
#
# Поколение 12
# Поколение 12: Лучший MSE: 506463.27240144537
#
# Поколение 13
# Поколение 13: Лучший MSE: 506463.27240144537
#
# Поколение 14
# Поколение 14: Лучший MSE: 505994.4597203969
#
# Поколение 15
# Поколение 15: Лучший MSE: 505994.4597203969
#
# Поколение 16
# Поколение 16: Лучший MSE: 505994.4597203969
#
# Поколение 17
# Поколение 17: Лучший MSE: 505473.7139754424
#
# Поколение 18
# Поколение 18: Лучший MSE: 505473.7139754424
#
# Поколение 19
# Поколение 19: Лучший MSE: 505473.6877796315
#
# Поколение 20
# Поколение 20: Лучший MSE: 505473.68594150845
#
# Поколение 21
# Поколение 21: Лучший MSE: 505473.68594150845
#
# Поколение 22
# Поколение 22: Лучший MSE: 505473.68594150845
#
# Поколение 23
# Поколение 23: Лучший MSE: 505473.68594150845
#
# Поколение 24
# Поколение 24: Лучший MSE: 505473.68594150845
#
# Поколение 25
# Поколение 25: Лучший MSE: 505473.68594150845
#
# Поколение 26
# Поколение 26: Лучший MSE: 505473.6859389106
#
# Поколение 27
# Поколение 27: Лучший MSE: 505473.68592400086
#
# Поколение 28
# Поколение 28: Лучший MSE: 505473.6859065566
#
# Поколение 29
# Поколение 29: Лучший MSE: 505473.6859065566
#
# Поколение 30
# Поколение 30: Лучший MSE: 505473.68590622506
#
# Поколение 1
# Поколение 1: Лучший MSE: 509807.9721117248
#
# Поколение 2
# Поколение 2: Лучший MSE: 509807.9721117248
#
# Поколение 3
# Поколение 3: Лучший MSE: 509807.9721117248
#
# Поколение 4
# Поколение 4: Лучший MSE: 509807.9721117248
#
# Поколение 5
# Поколение 5: Лучший MSE: 508753.8213029285
#
# Поколение 6
# Поколение 6: Лучший MSE: 508238.9796785335
#
# Поколение 7
# Поколение 7: Лучший MSE: 508238.9796785335
#
# Поколение 8
# Поколение 8: Лучший MSE: 508238.9796785335
#
# Поколение 9
# Поколение 9: Лучший MSE: 508238.9796785335
#
# Поколение 10
# Поколение 10: Лучший MSE: 507745.82267993764
#
# Поколение 11
# Поколение 11: Лучший MSE: 507745.82267993764
#
# Поколение 12
# Поколение 12: Лучший MSE: 507745.82267993764
#
# Поколение 13
# Поколение 13: Лучший MSE: 506739.2776889638
#
# Поколение 14
# Поколение 14: Лучший MSE: 506739.2776889638
#
# Поколение 15
# Поколение 15: Лучший MSE: 506739.2776889638
#
# Поколение 16
# Поколение 16: Лучший MSE: 506739.2776889638
#
# Поколение 17
# Поколение 17: Лучший MSE: 506654.52247556596
#
# Поколение 18
# Поколение 18: Лучший MSE: 506654.52247556596
#
# Поколение 19
# Поколение 19: Лучший MSE: 506654.52247556596
#
# Поколение 20
# Поколение 20: Лучший MSE: 506654.52247556596
#
# Поколение 21
# Поколение 21: Лучший MSE: 506654.52247556596
#
# Поколение 22
# Поколение 22: Лучший MSE: 506654.52247556596
#
# Поколение 23
# Поколение 23: Лучший MSE: 506520.4453972946
#
# Поколение 24
# Поколение 24: Лучший MSE: 506048.435817786
#
# Поколение 25
# Поколение 25: Лучший MSE: 506048.435817786
#
# Поколение 26
# Поколение 26: Лучший MSE: 506048.435817786
#
# Поколение 27
# Поколение 27: Лучший MSE: 506037.11233652546
#
# Поколение 28
# Поколение 28: Лучший MSE: 506037.1098406992
#
# Поколение 29
# Поколение 29: Лучший MSE: 506037.10983988596
#
# Поколение 30
# Поколение 30: Лучший MSE: 506037.10983988596
#
# Поколение 1
# Поколение 1: Лучший MSE: 512591.2587804974
#
# Поколение 2
# Поколение 2: Лучший MSE: 512591.2587804974
#
# Поколение 3
# Поколение 3: Лучший MSE: 512591.2587804974
#
# Поколение 4
# Поколение 4: Лучший MSE: 512591.2587804974
#
# Поколение 5
# Поколение 5: Лучший MSE: 511029.6842680013
#
# Поколение 6
# Поколение 6: Лучший MSE: 511029.6842680013
#
# Поколение 7
# Поколение 7: Лучший MSE: 510534.48626891786
#
# Поколение 8
# Поколение 8: Лучший MSE: 510534.48626891786
#
# Поколение 9
# Поколение 9: Лучший MSE: 510534.48626891786
#
# Поколение 10
# Поколение 10: Лучший MSE: 510534.48626891786
#
# Поколение 11
# Поколение 11: Лучший MSE: 509811.59923284577
#
# Поколение 12
# Поколение 12: Лучший MSE: 508024.89259615383
#
# Поколение 13
# Поколение 13: Лучший MSE: 507195.9387432875
#
# Поколение 14
# Поколение 14: Лучший MSE: 507195.9387432875
#
# Поколение 15
# Поколение 15: Лучший MSE: 507195.9387432875
#
# Поколение 16
# Поколение 16: Лучший MSE: 507195.9387432875
#
# Поколение 17
# Поколение 17: Лучший MSE: 507195.9387432875
#
# Поколение 18
# Поколение 18: Лучший MSE: 507195.9387432875
#
# Поколение 19
# Поколение 19: Лучший MSE: 507195.9387432875
#
# Поколение 20
# Поколение 20: Лучший MSE: 507195.9387432875
#
# Поколение 21
# Поколение 21: Лучший MSE: 507195.9387432875
#
# Поколение 22
# Поколение 22: Лучший MSE: 506057.7888364675
#
# Поколение 23
# Поколение 23: Лучший MSE: 506057.7888364675
#
# Поколение 24
# Поколение 24: Лучший MSE: 506033.3217704985
#
# Поколение 25
# Поколение 25: Лучший MSE: 505997.61231428134
#
# Поколение 26
# Поколение 26: Лучший MSE: 505997.61231428134
#
# Поколение 27
# Поколение 27: Лучший MSE: 505997.61231428134
#
# Поколение 28
# Поколение 28: Лучший MSE: 505473.74015162466
#
# Поколение 29
# Поколение 29: Лучший MSE: 505473.74015162466
#
# Поколение 30
# Поколение 30: Лучший MSE: 505473.74015162466
#
# Итоговая таблица с медианными значениями и гиперпараметрами:
#       Median MSE  Mode Best Generation  Median Time to Best Generation
# 0  510389.081647                    30                      205.446829  \
# 1  508185.736339                    17                      124.057993
# 2  507542.095615                    30                      360.353884
# 3  506037.109840                    30                      326.427833
#
#    Population Size  Mutation Rate  Offspring Ratio  Mutation Strength
# 0               19       0.239239         2.423736           0.158317  \
# 1               25       0.420926         1.879132           0.210155
# 2               33       0.148579         2.607310           0.213003
# 3               49       0.381269         2.081009           0.438579
#
#    Mutation Percent Genes  Elite Fraction
# 0                0.106731        0.169497
# 1                0.179910        0.097869
# 2                0.125633        0.166475
# 3                0.139581        0.195376
