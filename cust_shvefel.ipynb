# %%
# новый крутой вариант
import numpy as np
import matplotlib.pyplot as plt
import time
from pyDOE import lhs  # Библиотека для латинского гиперкуба

# Универсальная функция кэширования
def cache_function(func):
    cache = {}

    def cached_func(x):
        key = tuple(x) if isinstance(x, (list, np.ndarray)) else x
        
        # Если результат уже вычислен, возвращаем его
        if key in cache:
            return cache[key]
        
        # Иначе вычисляем результат и сохраняем его в кеш
        result = func(x)  # Вызываем переданную целевую функцию
        cache[key] = result
        return result
    
    return cached_func

# Пример целевой функции (Швефеля с 10 переменными)
def schwefel_function(x):
    return 418.9829 * len(x) - np.sum(x * np.sin(np.sqrt(np.abs(x))))  # Поддержка многомерности

# Кэшированная версия целевой функции
cached_objective_function = cache_function(schwefel_function)

# Инициализация популяции (выбор между случайной и латинским гиперкубом)
def initialize_population(pop_size, x_range, num_dimensions, method='random'):
    if method == 'random':
        # Случайное распределение для многомерной популяции
        return np.random.uniform(x_range[0], x_range[1], (pop_size, num_dimensions))
    elif method == 'lhs':  # Латинский гиперкуб
        lhs_samples = lhs(num_dimensions, samples=pop_size)  # num_dimensions измерений, pop_size выборок
        population = lhs_samples * (x_range[1] - x_range[0]) + x_range[0]  # Масштабируем выборки на нужный диапазон
        return population

# Селекция лучших индивидов с элитизмом (10% элиты)
def select_top_individuals_with_elitism(population, fitness_values, selection_percentage, elite_count=1):
    num_selected = int(len(population) * selection_percentage) - elite_count
    sorted_indices = np.argsort(fitness_values)
    elite_indices = sorted_indices[:elite_count]
    elite_population = population[elite_indices]
    elite_fitness = fitness_values[elite_indices]
    selected_indices = sorted_indices[elite_count:num_selected + elite_count]
    selected_population = population[selected_indices]
    selected_fitness = fitness_values[selected_indices]
    final_population = np.concatenate([elite_population, selected_population])
    final_fitness = np.concatenate([elite_fitness, selected_fitness])
    return final_population, final_fitness

# Скрещивание двух родителей
def crossover(parent1, parent2):
    return np.random.uniform(parent1, parent2)

# Создание потомков
def generate_offspring(selected_population, num_offspring):
    offspring = []
    for _ in range(num_offspring):
        parents = np.random.choice(len(selected_population), 2, replace=False)
        child = crossover(selected_population[parents[0]], selected_population[parents[1]])
        offspring.append(child)
    return np.array(offspring)

# Мутация потомков с новыми гиперпараметрами
def mutate(offspring, mutation_rate, mutation_strength, mutation_percent_genes, mutation_by_replacement, x_range):
    num_to_mutate = int(len(offspring) * mutation_rate)  # Сколько потомков подвергнутся мутации
    indices_to_mutate = np.random.choice(len(offspring), num_to_mutate, replace=False)

    for i in indices_to_mutate:  # Для каждого выбранного потомка
        num_genes_to_mutate = int(offspring.shape[1] * mutation_percent_genes)  # Сколько генов будет изменено
        genes_to_mutate = np.random.choice(offspring.shape[1], num_genes_to_mutate, replace=False)

        for gene_idx in genes_to_mutate:
            if mutation_by_replacement:
                # Полная замена гена на случайное значение
                offspring[i, gene_idx] = np.random.uniform(x_range[0], x_range[1])
            else:
                # Добавляем случайное смещение
                mutation = np.random.uniform(-mutation_strength, mutation_strength) * (x_range[1] - x_range[0])
                offspring[i, gene_idx] += mutation
                offspring[i, gene_idx] = np.clip(offspring[i, gene_idx], x_range[0], x_range[1])  # Ограничиваем диапазон

    return offspring

# Гиперпараметры
population_size = 500
x_range = (-500, 500)  # Диапазон для функции Швефеля
num_dimensions = 10  # Количество переменных (размерность)
selection_percentage = 0.5  # 50% популяции
offspring_ratio = 2.0  # Потомки в 2 раза больше родителей
mutation_rate = 0.5  # 30% потомков подвергаются мутации
mutation_strength = 0.3  # Сила мутации (30% диапазона)
mutation_percent_genes = 0.1  # 20% генов (параметров) будут изменены
mutation_by_replacement = True  # Полная замена генов при мутации
elite_fraction = 0.1  # 10% элитизма (1 особь)
num_iterations = 400  # Число итераций (гиперпараметр)
initialization_method = 'random'  # Способ инициализации: 'random' или 'lhs'
early_stopping_patience = 30  # Число итераций без улучшений до остановки
delta_threshold = 0.0001  # Минимальное изменение целевой функции для остановки

# Шаги
population = initialize_population(population_size, x_range, num_dimensions, method=initialization_method)
fitness_values = np.array([cached_objective_function(ind) for ind in population])

# Основной цикл
best_solution = None
best_fitness = float('inf')
no_improvement_count = 0  # Счётчик итераций без улучшений
delta_stability_count = 0  # Счетчик изменений по малому изменению

# Начало общего таймера для всех итераций
global_start_time = time.time()

for generation in range(num_iterations):
    start_time = time.time()  # Засекаем время начала итерации
    
    # Отбор лучших 50% индивидов с элитизмом
    selected_population, selected_fitness = select_top_individuals_with_elitism(population, fitness_values, selection_percentage, elite_count=int(elite_fraction * population_size))
    
    # Количество потомков
    num_offspring = int(len(selected_population) * offspring_ratio)
    offspring = generate_offspring(selected_population, num_offspring)

    # Мутация с новыми гиперпараметрами
    offspring = mutate(offspring, mutation_rate, mutation_strength, mutation_percent_genes, mutation_by_replacement, x_range)

    # Объединение родителей и потомков
    combined_population = np.concatenate([selected_population, offspring])
    combined_fitness = np.array([cached_objective_function(ind) for ind in combined_population])

    # Отбор лучших особей
    final_population, final_fitness = select_top_individuals_with_elitism(combined_population, combined_fitness, population_size / len(combined_population), elite_count=int(elite_fraction * population_size))

    # Обновляем популяцию
    population = final_population
    fitness_values = final_fitness

    # Находим лучшее решение
    current_best_fitness = np.min(final_fitness)
    current_best_solution = final_population[np.argmin(final_fitness)]
    
    fitness_delta = np.abs(current_best_fitness - best_fitness)
    
    # Условие обновления лучшего решения
    if current_best_fitness < best_fitness:
        best_fitness = current_best_fitness
        best_solution = current_best_solution
        no_improvement_count = 0  # Сброс счётчика при улучшении
        delta_stability_count = 0  # Сброс счетчика изменений
    else:
        no_improvement_count += 1  # Увеличиваем счётчик если нет улучшения

        # Проверка изменений целевой функции
        if fitness_delta < delta_threshold:
            delta_stability_count += 1
        else:
            delta_stability_count = 0  # Сброс если изменения есть

    # Время итерации и общее время с начала всего процесса
    iteration_time = time.time() - global_start_time

    # Вывод результатов итерации
    print(f"Итерация {generation+1}, значение цф = {best_fitness:.6f}, время = {iteration_time:.4f} секунд")

    # Early stopping: Если нет улучшений за последние 10 итераций, останавливаем алгоритм
    if no_improvement_count >= early_stopping_patience:
        print(f"Early stopping на {generation+1} итерации. Нет улучшений за {early_stopping_patience} итераций.")
        break
# Out:
# Итерация 1, значение цф = 2236.406213, время = 0.0850 секунд
# Итерация 2, значение цф = 2236.406213, время = 0.1530 секунд
# Итерация 3, значение цф = 2236.406213, время = 0.2020 секунд
# Итерация 4, значение цф = 2236.406213, время = 0.2480 секунд
# Итерация 5, значение цф = 2236.406213, время = 0.2880 секунд
# Итерация 6, значение цф = 2236.406213, время = 0.3300 секунд
# Итерация 7, значение цф = 2203.925936, время = 0.3640 секунд
# Итерация 8, значение цф = 2111.766074, время = 0.3940 секунд
# Итерация 9, значение цф = 2111.766074, время = 0.4260 секунд
# Итерация 10, значение цф = 2111.766074, время = 0.4550 секунд
# Итерация 11, значение цф = 2111.766074, время = 0.4840 секунд
# Итерация 12, значение цф = 2111.766074, время = 0.5240 секунд
# Итерация 13, значение цф = 2111.766074, время = 0.5780 секунд
# Итерация 14, значение цф = 2111.766074, время = 0.6610 секунд
# Итерация 15, значение цф = 2111.766074, время = 0.7270 секунд
# Итерация 16, значение цф = 2111.766074, время = 0.7910 секунд
# Итерация 17, значение цф = 2111.766074, время = 0.8470 секунд
# Итерация 18, значение цф = 2073.050220, время = 0.9510 секунд
# Итерация 19, значение цф = 2073.050220, время = 1.0070 секунд
# Итерация 20, значение цф = 2073.050220, время = 1.0610 секунд
# Итерация 21, значение цф = 2073.050220, время = 1.1160 секунд
# Итерация 22, значение цф = 2073.050220, время = 1.1540 секунд
# Итерация 23, значение цф = 2073.050220, время = 1.2140 секунд
# Итерация 24, значение цф = 2073.050220, время = 1.3110 секунд
# Итерация 25, значение цф = 2073.050220, время = 1.3630 секунд
# Итерация 26, значение цф = 2073.050220, время = 1.4810 секунд
# Итерация 27, значение цф = 1967.666324, время = 1.5460 секунд
# Итерация 28, значение цф = 1967.666324, время = 1.6120 секунд
# Итерация 29, значение цф = 1967.666324, время = 1.6830 секунд
# Итерация 30, значение цф = 1936.433975, время = 1.7260 секунд
# Итерация 31, значение цф = 1936.433975, время = 1.7650 секунд
# Итерация 32, значение цф = 1936.433975, время = 1.8110 секунд
# Итерация 33, значение цф = 1936.433975, время = 1.8560 секунд
# Итерация 34, значение цф = 1936.433975, время = 1.8970 секунд
# Итерация 35, значение цф = 1819.857123, время = 1.9350 секунд
# Итерация 36, значение цф = 1819.857123, время = 1.9670 секунд
# Итерация 37, значение цф = 1819.857123, время = 2.0050 секунд
# Итерация 38, значение цф = 1819.857123, время = 2.0370 секунд
# Итерация 39, значение цф = 1819.857123, время = 2.0680 секунд
# Итерация 40, значение цф = 1819.857123, время = 2.0980 секунд
# Итерация 41, значение цф = 1740.558349, время = 2.1350 секунд
# Итерация 42, значение цф = 1633.672283, время = 2.1700 секунд
# Итерация 43, значение цф = 1633.672283, время = 2.2050 секунд
# Итерация 44, значение цф = 1633.672283, время = 2.2470 секунд
# Итерация 45, значение цф = 1566.576709, время = 2.2890 секунд
# Итерация 46, значение цф = 1566.576709, время = 2.3380 секунд
# Итерация 47, значение цф = 1453.034294, время = 2.3890 секунд
# Итерация 48, значение цф = 1453.034294, время = 2.4320 секунд
# Итерация 49, значение цф = 1453.034294, время = 2.4640 секунд
# Итерация 50, значение цф = 1453.034294, время = 2.5050 секунд
# Итерация 51, значение цф = 1453.034294, время = 2.5420 секунд
# Итерация 52, значение цф = 1364.290939, время = 2.5750 секунд
# Итерация 53, значение цф = 1364.290939, время = 2.6090 секунд
# Итерация 54, значение цф = 1364.290939, время = 2.6410 секунд
# Итерация 55, значение цф = 1364.290939, время = 2.6720 секунд
# Итерация 56, значение цф = 1364.290939, время = 2.7100 секунд
# Итерация 57, значение цф = 1280.514851, время = 2.7470 секунд
# Итерация 58, значение цф = 1280.514851, время = 2.7780 секунд
# Итерация 59, значение цф = 1280.514851, время = 2.8110 секунд
# Итерация 60, значение цф = 1280.514851, время = 2.8490 секунд
# Итерация 61, значение цф = 1280.514851, время = 2.8810 секунд
# Итерация 62, значение цф = 1249.782456, время = 2.9120 секунд
# Итерация 63, значение цф = 1077.760265, время = 2.9580 секунд
# Итерация 64, значение цф = 1077.760265, время = 2.9910 секунд
# Итерация 65, значение цф = 1077.760265, время = 3.0220 секунд
# Итерация 66, значение цф = 1077.760265, время = 3.0580 секунд
# Итерация 67, значение цф = 1077.760265, время = 3.0890 секунд
# Итерация 68, значение цф = 1077.760265, время = 3.1200 секунд
# Итерация 69, значение цф = 1077.760265, время = 3.1540 секунд
# Итерация 70, значение цф = 1077.760265, время = 3.1960 секунд
# Итерация 71, значение цф = 930.273998, время = 3.2310 секунд
# Итерация 72, значение цф = 930.273998, время = 3.2640 секунд
# Итерация 73, значение цф = 930.273998, время = 3.2960 секунд
# Итерация 74, значение цф = 862.656114, время = 3.3260 секунд
# Итерация 75, значение цф = 862.656114, время = 3.3590 секунд
# Итерация 76, значение цф = 862.656114, время = 3.3900 секунд
# Итерация 77, значение цф = 834.388886, время = 3.4310 секунд
# Итерация 78, значение цф = 834.388886, время = 3.4760 секунд
# Итерация 79, значение цф = 834.388886, время = 3.5070 секунд
# Итерация 80, значение цф = 834.388886, время = 3.5370 секунд
# Итерация 81, значение цф = 834.388886, время = 3.5690 секунд
# Итерация 82, значение цф = 815.506133, время = 3.6020 секунд
# Итерация 83, значение цф = 812.876783, время = 3.6320 секунд
# Итерация 84, значение цф = 812.876783, время = 3.6660 секунд
# Итерация 85, значение цф = 738.119867, время = 3.7070 секунд
# Итерация 86, значение цф = 688.224136, время = 3.7390 секунд
# Итерация 87, значение цф = 688.224136, время = 3.7720 секунд
# Итерация 88, значение цф = 688.224136, время = 3.8040 секунд
# Итерация 89, значение цф = 688.224136, время = 3.8350 секунд
# Итерация 90, значение цф = 582.116258, время = 3.8690 секунд
# Итерация 91, значение цф = 582.116258, время = 3.9160 секунд
# Итерация 92, значение цф = 470.477140, время = 3.9630 секунд
# Итерация 93, значение цф = 470.477140, время = 4.0050 секунд
# Итерация 94, значение цф = 470.477140, время = 4.0400 секунд
# Итерация 95, значение цф = 470.477140, время = 4.0740 секунд
# Итерация 96, значение цф = 470.477140, время = 4.1070 секунд
# Итерация 97, значение цф = 454.495676, время = 4.1490 секунд
# Итерация 98, значение цф = 454.495676, время = 4.1960 секунд
# Итерация 99, значение цф = 427.945269, время = 4.2440 секунд
# Итерация 100, значение цф = 424.834130, время = 4.2850 секунд
# Итерация 101, значение цф = 424.834130, время = 4.3160 секунд
# Итерация 102, значение цф = 424.834130, время = 4.3570 секунд
# Итерация 103, значение цф = 279.391276, время = 4.4370 секунд
# Итерация 104, значение цф = 279.391276, время = 4.4860 секунд
# Итерация 105, значение цф = 279.391276, время = 4.5260 секунд
# Итерация 106, значение цф = 272.748273, время = 4.5660 секунд
# Итерация 107, значение цф = 265.645740, время = 4.6110 секунд
# Итерация 108, значение цф = 194.172277, время = 4.6460 секунд
# Итерация 109, значение цф = 194.172277, время = 4.6820 секунд
# Итерация 110, значение цф = 194.172277, время = 4.7170 секунд
# Итерация 111, значение цф = 167.666171, время = 4.7470 секунд
# Итерация 112, значение цф = 167.666171, время = 4.7761 секунд
# Итерация 113, значение цф = 167.666171, время = 4.8070 секунд
# Итерация 114, значение цф = 167.666171, время = 4.8460 секунд
# Итерация 115, значение цф = 122.702915, время = 4.8770 секунд
# Итерация 116, значение цф = 122.702915, время = 4.9100 секунд
# Итерация 117, значение цф = 122.702915, время = 4.9400 секунд
# Итерация 118, значение цф = 92.997731, время = 4.9700 секунд
# Итерация 119, значение цф = 62.790436, время = 5.0020 секунд
# Итерация 120, значение цф = 62.790436, время = 5.0300 секунд
# Итерация 121, значение цф = 62.790436, время = 5.0640 секунд
# Итерация 122, значение цф = 60.535452, время = 5.1000 секунд
# Итерация 123, значение цф = 47.757121, время = 5.1350 секунд
# Итерация 124, значение цф = 47.757121, время = 5.1640 секунд
# Итерация 125, значение цф = 40.137143, время = 5.1951 секунд
# Итерация 126, значение цф = 31.699107, время = 5.2240 секунд
# Итерация 127, значение цф = 29.792730, время = 5.2530 секунд
# Итерация 128, значение цф = 29.792730, время = 5.2850 секунд
# Итерация 129, значение цф = 29.792730, время = 5.3200 секунд
# Итерация 130, значение цф = 29.792730, время = 5.3490 секунд
# Итерация 131, значение цф = 26.403459, время = 5.3820 секунд
# Итерация 132, значение цф = 21.607955, время = 5.4140 секунд
# Итерация 133, значение цф = 21.607955, время = 5.4441 секунд
# Итерация 134, значение цф = 18.426032, время = 5.4740 секунд
# Итерация 135, значение цф = 18.426032, время = 5.5100 секунд
# Итерация 136, значение цф = 18.426032, время = 5.5460 секунд
# Итерация 137, значение цф = 18.426032, время = 5.5771 секунд
# Итерация 138, значение цф = 18.379496, время = 5.6120 секунд
# Итерация 139, значение цф = 18.379496, время = 5.6420 секунд
# Итерация 140, значение цф = 16.080170, время = 5.6710 секунд
# Итерация 141, значение цф = 16.080170, время = 5.7010 секунд
# Итерация 142, значение цф = 14.463324, время = 5.7351 секунд
# Итерация 143, значение цф = 14.463324, время = 5.7680 секунд
# Итерация 144, значение цф = 11.736429, время = 5.7990 секунд
# Итерация 145, значение цф = 11.736429, время = 5.8310 секунд
# Итерация 146, значение цф = 11.736429, время = 5.8630 секунд
# Итерация 147, значение цф = 11.223628, время = 5.8920 секунд
# Итерация 148, значение цф = 9.717633, время = 5.9220 секунд
# Итерация 149, значение цф = 9.717633, время = 5.9540 секунд
# Итерация 150, значение цф = 9.717633, время = 5.9910 секунд
# Итерация 151, значение цф = 9.408612, время = 6.0231 секунд
# Итерация 152, значение цф = 9.009680, время = 6.0530 секунд
# Итерация 153, значение цф = 8.409693, время = 6.0840 секунд
# Итерация 154, значение цф = 7.833509, время = 6.1130 секунд
# Итерация 155, значение цф = 7.572080, время = 6.1431 секунд
# Итерация 156, значение цф = 7.572080, время = 6.1771 секунд
# Итерация 157, значение цф = 7.029368, время = 6.2111 секунд
# Итерация 158, значение цф = 7.029368, время = 6.2441 секунд
# Итерация 159, значение цф = 6.291494, время = 6.2741 секунд
# Итерация 160, значение цф = 6.291494, время = 6.3061 секунд
# Итерация 161, значение цф = 6.291494, время = 6.3441 секунд
# Итерация 162, значение цф = 5.769253, время = 6.3731 секунд
# Итерация 163, значение цф = 5.641857, время = 6.4101 секунд
# Итерация 164, значение цф = 5.641857, время = 6.4441 секунд
# Итерация 165, значение цф = 5.196521, время = 6.4761 секунд
# Итерация 166, значение цф = 5.196521, время = 6.5050 секунд
# Итерация 167, значение цф = 5.196521, время = 6.5351 секунд
# Итерация 168, значение цф = 5.196521, время = 6.5631 секунд
# Итерация 169, значение цф = 4.836615, время = 6.5961 секунд
# Итерация 170, значение цф = 4.836615, время = 6.6231 секунд
# Итерация 171, значение цф = 4.591676, время = 6.6711 секунд
# Итерация 172, значение цф = 4.327283, время = 6.7101 секунд
# Итерация 173, значение цф = 4.136570, время = 6.7401 секунд
# Итерация 174, значение цф = 3.973382, время = 6.7731 секунд
# Итерация 175, значение цф = 3.862374, время = 6.8051 секунд
# Итерация 176, значение цф = 3.439099, время = 6.8351 секунд
# Итерация 177, значение цф = 3.205532, время = 6.8651 секунд
# Итерация 178, значение цф = 2.622527, время = 6.9061 секунд
# Итерация 179, значение цф = 2.622527, время = 6.9671 секунд
# Итерация 180, значение цф = 2.586666, время = 7.0251 секунд
# Итерация 181, значение цф = 2.122898, время = 7.0541 секунд
# Итерация 182, значение цф = 2.122898, время = 7.0851 секунд
# Итерация 183, значение цф = 2.122898, время = 7.1161 секунд
# Итерация 184, значение цф = 2.108417, время = 7.1511 секунд
# Итерация 185, значение цф = 2.050674, время = 7.1831 секунд
# Итерация 186, значение цф = 2.008893, время = 7.2161 секунд
# Итерация 187, значение цф = 1.800941, время = 7.2471 секунд
# Итерация 188, значение цф = 1.800941, время = 7.2761 секунд
# Итерация 189, значение цф = 1.770087, время = 7.3121 секунд
# Итерация 190, значение цф = 1.680857, время = 7.3411 секунд
# Итерация 191, значение цф = 1.462622, время = 7.3761 секунд
# Итерация 192, значение цф = 1.462622, время = 7.4111 секунд
# Итерация 193, значение цф = 1.195066, время = 7.4411 секунд
# Итерация 194, значение цф = 1.140508, время = 7.4711 секунд
# Итерация 195, значение цф = 1.068110, время = 7.5011 секунд
# Итерация 196, значение цф = 1.068110, время = 7.5331 секунд
# Итерация 197, значение цф = 1.041979, время = 7.5631 секунд
# Итерация 198, значение цф = 0.939395, время = 7.5971 секунд
# Итерация 199, значение цф = 0.857641, время = 7.6331 секунд
# Итерация 200, значение цф = 0.822707, время = 7.6641 секунд
# Итерация 201, значение цф = 0.769805, время = 7.6961 секунд
# Итерация 202, значение цф = 0.759805, время = 7.7271 секунд
# Итерация 203, значение цф = 0.712010, время = 7.7561 секунд
# Итерация 204, значение цф = 0.712010, время = 7.7861 секунд
# Итерация 205, значение цф = 0.669784, время = 7.8211 секунд
# Итерация 206, значение цф = 0.654384, время = 7.8541 секунд
# Итерация 207, значение цф = 0.654384, время = 7.8841 секунд
# Итерация 208, значение цф = 0.609937, время = 7.9161 секунд
# Итерация 209, значение цф = 0.609937, время = 7.9471 секунд
# Итерация 210, значение цф = 0.599646, время = 7.9771 секунд
# Итерация 211, значение цф = 0.574778, время = 8.0101 секунд
# Итерация 212, значение цф = 0.556139, время = 8.0481 секунд
# Итерация 213, значение цф = 0.556139, время = 8.0801 секунд
# Итерация 214, значение цф = 0.556139, время = 8.1111 секунд
# Итерация 215, значение цф = 0.545822, время = 8.1441 секунд
# Итерация 216, значение цф = 0.539015, время = 8.1741 секунд
# Итерация 217, значение цф = 0.525207, время = 8.2041 секунд
# Итерация 218, значение цф = 0.524812, время = 8.2391 секунд
# Итерация 219, значение цф = 0.511016, время = 8.2741 секунд
# Итерация 220, значение цф = 0.511016, время = 8.3061 секунд
# Итерация 221, значение цф = 0.498592, время = 8.3371 секунд
# Итерация 222, значение цф = 0.468452, время = 8.3701 секунд
# Итерация 223, значение цф = 0.462488, время = 8.4001 секунд
# Итерация 224, значение цф = 0.462488, время = 8.4291 секунд
# Итерация 225, значение цф = 0.454128, время = 8.4661 секунд
# Итерация 226, значение цф = 0.451147, время = 8.5011 секунд
# Итерация 227, значение цф = 0.451147, время = 8.5331 секунд
# Итерация 228, значение цф = 0.437952, время = 8.5661 секунд
# Итерация 229, значение цф = 0.432857, время = 8.5961 секунд
# Итерация 230, значение цф = 0.423204, время = 8.6251 секунд
# Итерация 231, значение цф = 0.421709, время = 8.6541 секунд
# Итерация 232, значение цф = 0.333946, время = 8.6941 секунд
# Итерация 233, значение цф = 0.333946, время = 8.7311 секунд
# Итерация 234, значение цф = 0.321803, время = 8.7641 секунд
# Итерация 235, значение цф = 0.313676, время = 8.7941 секунд
# Итерация 236, значение цф = 0.313676, время = 8.8241 секунд
# Итерация 237, значение цф = 0.313324, время = 8.8581 секунд
# Итерация 238, значение цф = 0.309565, время = 8.8881 секунд
# Итерация 239, значение цф = 0.300363, время = 8.9241 секунд
# Итерация 240, значение цф = 0.279253, время = 8.9611 секунд
# Итерация 241, значение цф = 0.279253, время = 8.9931 секунд
# Итерация 242, значение цф = 0.275055, время = 9.0231 секунд
# Итерация 243, значение цф = 0.275055, время = 9.0531 секунд
# Итерация 244, значение цф = 0.267128, время = 9.0871 секунд
# Итерация 245, значение цф = 0.250827, время = 9.1171 секунд
# Итерация 246, значение цф = 0.250827, время = 9.1491 секунд
# Итерация 247, значение цф = 0.250827, время = 9.1861 секунд
# Итерация 248, значение цф = 0.250827, время = 9.2161 секунд
# Итерация 249, значение цф = 0.247335, время = 9.2461 секунд
# Итерация 250, значение цф = 0.247335, время = 9.2781 секунд
# Итерация 251, значение цф = 0.241462, время = 9.3081 секунд
# Итерация 252, значение цф = 0.241254, время = 9.3381 секунд
# Итерация 253, значение цф = 0.241254, время = 9.3711 секунд
# Итерация 254, значение цф = 0.222647, время = 9.4041 секунд
# Итерация 255, значение цф = 0.222647, время = 9.4401 секунд
# Итерация 256, значение цф = 0.222647, время = 9.4701 секунд
# Итерация 257, значение цф = 0.217756, время = 9.4981 секунд
# Итерация 258, значение цф = 0.216947, время = 9.5321 секунд
# Итерация 259, значение цф = 0.216947, время = 9.5601 секунд
# Итерация 260, значение цф = 0.199372, время = 9.5931 секунд
# Итерация 261, значение цф = 0.199372, время = 9.6321 секунд
# Итерация 262, значение цф = 0.199372, время = 9.6641 секунд
# Итерация 263, значение цф = 0.199372, время = 9.7001 секунд
# Итерация 264, значение цф = 0.193234, время = 9.7311 секунд
# Итерация 265, значение цф = 0.193234, время = 9.7611 секунд
# Итерация 266, значение цф = 0.193234, время = 9.7911 секунд
# Итерация 267, значение цф = 0.193234, время = 9.8261 секунд
# Итерация 268, значение цф = 0.193234, время = 9.8591 секунд
# Итерация 269, значение цф = 0.193234, время = 9.8931 секунд
# Итерация 270, значение цф = 0.190899, время = 9.9271 секунд
# Итерация 271, значение цф = 0.187972, время = 9.9581 секунд
# Итерация 272, значение цф = 0.187972, время = 9.9871 секунд
# Итерация 273, значение цф = 0.187972, время = 10.0221 секунд
# Итерация 274, значение цф = 0.187972, время = 10.0581 секунд
# Итерация 275, значение цф = 0.187972, время = 10.0921 секунд
# Итерация 276, значение цф = 0.187972, время = 10.1271 секунд
# Итерация 277, значение цф = 0.187972, время = 10.1581 секунд
# Итерация 278, значение цф = 0.187972, время = 10.1861 секунд
# Итерация 279, значение цф = 0.187972, время = 10.2171 секунд
# Итерация 280, значение цф = 0.187972, время = 10.2511 секунд
# Итерация 281, значение цф = 0.133016, время = 10.2891 секунд
# Итерация 282, значение цф = 0.133016, время = 10.3271 секунд
# Итерация 283, значение цф = 0.133016, время = 10.3571 секунд
# Итерация 284, значение цф = 0.133016, время = 10.3871 секунд
# Итерация 285, значение цф = 0.133016, время = 10.4191 секунд
# Итерация 286, значение цф = 0.133016, время = 10.4491 секунд
# Итерация 287, значение цф = 0.133016, время = 10.4801 секунд
# Итерация 288, значение цф = 0.133016, время = 10.5131 секунд
# Итерация 289, значение цф = 0.133016, время = 10.5501 секунд
# Итерация 290, значение цф = 0.133016, время = 10.5801 секунд
# Итерация 291, значение цф = 0.129144, время = 10.6131 секунд
# Итерация 292, значение цф = 0.126326, время = 10.6471 секунд
# Итерация 293, значение цф = 0.108709, время = 10.6781 секунд
# Итерация 294, значение цф = 0.105977, время = 10.7081 секунд
# Итерация 295, значение цф = 0.102650, время = 10.7481 секунд
# Итерация 296, значение цф = 0.099662, время = 10.7791 секунд
# Итерация 297, значение цф = 0.092713, время = 10.8101 секунд
# Итерация 298, значение цф = 0.087661, время = 10.8411 секунд
# Итерация 299, значение цф = 0.085710, время = 10.8711 секунд
# Итерация 300, значение цф = 0.085710, время = 10.9011 секунд
# Итерация 301, значение цф = 0.085710, время = 10.9301 секунд
# Итерация 302, значение цф = 0.085710, время = 10.9651 секунд
# Итерация 303, значение цф = 0.083386, время = 11.0011 секунд
# Итерация 304, значение цф = 0.083386, время = 11.0321 секунд
# Итерация 305, значение цф = 0.083063, время = 11.0621 секунд
# Итерация 306, значение цф = 0.082943, время = 11.0991 секунд
# Итерация 307, значение цф = 0.082691, время = 11.1281 секунд
# Итерация 308, значение цф = 0.081480, время = 11.1581 секунд
# Итерация 309, значение цф = 0.081429, время = 11.1911 секунд
# Итерация 310, значение цф = 0.080616, время = 11.2281 секунд
# Итерация 311, значение цф = 0.080387, время = 11.3271 секунд
# Итерация 312, значение цф = 0.080387, время = 11.3801 секунд
# Итерация 313, значение цф = 0.080141, время = 11.4351 секунд
# Итерация 314, значение цф = 0.080059, время = 11.4821 секунд
# Итерация 315, значение цф = 0.079286, время = 11.5141 секунд
# Итерация 316, значение цф = 0.079286, время = 11.5441 секунд
# Итерация 317, значение цф = 0.079131, время = 11.5731 секунд
# Итерация 318, значение цф = 0.079131, время = 11.6051 секунд
# Итерация 319, значение цф = 0.072629, время = 11.6361 секунд
# Итерация 320, значение цф = 0.072629, время = 11.6701 секунд
# Итерация 321, значение цф = 0.065364, время = 11.7171 секунд
# Итерация 322, значение цф = 0.064157, время = 11.7641 секунд
# Итерация 323, значение цф = 0.060942, время = 11.7971 секунд
# Итерация 324, значение цф = 0.060942, время = 11.8281 секунд
# Итерация 325, значение цф = 0.060942, время = 11.8581 секунд
# Итерация 326, значение цф = 0.060942, время = 11.8891 секунд
# Итерация 327, значение цф = 0.054617, время = 11.9341 секунд
# Итерация 328, значение цф = 0.052778, время = 11.9651 секунд
# Итерация 329, значение цф = 0.047149, время = 11.9951 секунд
# Итерация 330, значение цф = 0.046469, время = 12.0281 секунд
# Итерация 331, значение цф = 0.046336, время = 12.0581 секунд
# Итерация 332, значение цф = 0.045589, время = 12.0881 секунд
# Итерация 333, значение цф = 0.045279, время = 12.1211 секунд
# Итерация 334, значение цф = 0.045279, время = 12.1581 секунд
# Итерация 335, значение цф = 0.044160, время = 12.1861 секунд
# Итерация 336, значение цф = 0.043869, время = 12.2211 секунд
# Итерация 337, значение цф = 0.043869, время = 12.2521 секунд
# Итерация 338, значение цф = 0.043869, время = 12.2791 секунд
# Итерация 339, значение цф = 0.043639, время = 12.3091 секунд
# Итерация 340, значение цф = 0.043639, время = 12.3421 секунд
# Итерация 341, значение цф = 0.043639, время = 12.3791 секунд
# Итерация 342, значение цф = 0.043639, время = 12.4101 секунд
# Итерация 343, значение цф = 0.043534, время = 12.4411 секунд
# Итерация 344, значение цф = 0.043275, время = 12.4741 секунд
# Итерация 345, значение цф = 0.043275, время = 12.5041 секунд
# Итерация 346, значение цф = 0.043210, время = 12.5351 секунд
# Итерация 347, значение цф = 0.041321, время = 12.5661 секунд
# Итерация 348, значение цф = 0.041321, время = 12.6031 секунд
# Итерация 349, значение цф = 0.041321, время = 12.6411 секунд
# Итерация 350, значение цф = 0.041321, время = 12.6731 секунд
# Итерация 351, значение цф = 0.041321, время = 12.7041 секунд
# Итерация 352, значение цф = 0.039504, время = 12.7351 секунд
# Итерация 353, значение цф = 0.039504, время = 12.7651 секунд
# Итерация 354, значение цф = 0.039110, время = 12.8001 секунд
# Итерация 355, значение цф = 0.038676, время = 12.8341 секунд
# Итерация 356, значение цф = 0.038477, время = 12.8661 секунд
# Итерация 357, значение цф = 0.038380, время = 12.8991 секунд
# Итерация 358, значение цф = 0.038380, время = 12.9281 секунд
# Итерация 359, значение цф = 0.037971, время = 12.9581 секунд
# Итерация 360, значение цф = 0.017976, время = 12.9901 секунд
# Итерация 361, значение цф = 0.017976, время = 13.0211 секунд
# Итерация 362, значение цф = 0.017976, время = 13.0551 секунд
# Итерация 363, значение цф = 0.016624, время = 13.0861 секунд
# Итерация 364, значение цф = 0.016242, время = 13.1211 секунд
# Итерация 365, значение цф = 0.016242, время = 13.1501 секунд
# Итерация 366, значение цф = 0.016020, время = 13.1791 секунд
# Итерация 367, значение цф = 0.016020, время = 13.2121 секунд
# Итерация 368, значение цф = 0.015931, время = 13.2511 секунд
# Итерация 369, значение цф = 0.014930, время = 13.2841 секунд
# Итерация 370, значение цф = 0.014915, время = 13.3211 секунд
# Итерация 371, значение цф = 0.014915, время = 13.3501 секунд
# Итерация 372, значение цф = 0.014915, время = 13.3791 секунд
# Итерация 373, значение цф = 0.014655, время = 13.4091 секунд
# Итерация 374, значение цф = 0.014655, время = 13.4421 секунд
# Итерация 375, значение цф = 0.014646, время = 13.4741 секунд
# Итерация 376, значение цф = 0.013623, время = 13.5111 секунд
# Итерация 377, значение цф = 0.013623, время = 13.5411 секунд
# Итерация 378, значение цф = 0.013623, время = 13.5701 секунд
# Итерация 379, значение цф = 0.013623, время = 13.6011 секунд
# Итерация 380, значение цф = 0.013623, время = 13.6331 секунд
# Итерация 381, значение цф = 0.013617, время = 13.6631 секунд
# Итерация 382, значение цф = 0.013298, время = 13.6981 секунд
# Итерация 383, значение цф = 0.013298, время = 13.7361 секунд
# Итерация 384, значение цф = 0.013132, время = 13.7681 секунд
# Итерация 385, значение цф = 0.013054, время = 13.7971 секунд
# Итерация 386, значение цф = 0.013054, время = 13.8311 секунд
# Итерация 387, значение цф = 0.013054, время = 13.8611 секунд
# Итерация 388, значение цф = 0.013054, время = 13.8901 секунд
# Итерация 389, значение цф = 0.013033, время = 13.9241 секунд
# Итерация 390, значение цф = 0.013028, время = 13.9641 секунд
# Итерация 391, значение цф = 0.012995, время = 13.9951 секунд
# Итерация 392, значение цф = 0.012870, время = 14.0261 секунд
# Итерация 393, значение цф = 0.012860, время = 14.0581 секунд
# Итерация 394, значение цф = 0.012860, время = 14.0871 секунд
# Итерация 395, значение цф = 0.012860, время = 14.1181 секунд
# Итерация 396, значение цф = 0.012860, время = 14.1491 секунд
# Итерация 397, значение цф = 0.012834, время = 14.1881 секунд
# Итерация 398, значение цф = 0.012834, время = 14.2211 секунд
# Итерация 399, значение цф = 0.012834, время = 14.2531 секунд
# Итерация 400, значение цф = 0.012812, время = 14.2841 секунд

# %%
#вариант по 30*30 прогонов для исследования
import random
import numpy as np
import pandas as pd
import gc
import time
from pyDOE import lhs

# Универсальная функция кэширования с возможностью очистки кэша
class CacheFunction:
    def __init__(self, func):
        self.func = func
        self.cache = {}

    def __call__(self, x):
        key = tuple(x) if isinstance(x, (list, np.ndarray)) else x
        if key in self.cache:
            return self.cache[key]
        result = self.func(x)
        self.cache[key] = result
        return result

    def clear_cache(self):
        self.cache.clear()

# Пример целевой функции (Швефеля с 10 переменными)
def schwefel_function(x):
    return 418.9829 * len(x) - np.sum(x * np.sin(np.sqrt(np.abs(x))))

# Кэшированная версия целевой функции
cached_objective_function = CacheFunction(schwefel_function)

# Инициализация популяции (выбор между случайной и латинским гиперкубом)
def initialize_population(pop_size, x_range, num_dimensions, method='random'):
    if method == 'random':
        return np.random.uniform(x_range[0], x_range[1], (pop_size, num_dimensions))
    elif method == 'lhs':  # Латинский гиперкуб
        lhs_samples = lhs(num_dimensions, samples=pop_size)
        population = lhs_samples * (x_range[1] - x_range[0]) + x_range[0]
        return population

# Селекция лучших индивидов с элитизмом
def select_top_individuals_with_elitism(population, fitness_values, selection_percentage, elite_count=1):
    num_selected = int(len(population) * selection_percentage) - elite_count
    sorted_indices = np.argsort(fitness_values)
    elite_indices = sorted_indices[:elite_count]
    elite_population = population[elite_indices]
    elite_fitness = fitness_values[elite_indices]
    selected_indices = sorted_indices[elite_count:num_selected + elite_count]
    selected_population = population[selected_indices]
    selected_fitness = fitness_values[selected_indices]
    final_population = np.concatenate([elite_population, selected_population])
    final_fitness = np.concatenate([elite_fitness, selected_fitness])
    return final_population, final_fitness

# Скрещивание двух родителей
def crossover(parent1, parent2):
    return np.random.uniform(parent1, parent2)

# Создание потомков
def generate_offspring(selected_population, num_offspring):
    offspring = []
    for _ in range(num_offspring):
        parents = np.random.choice(len(selected_population), 2, replace=False)
        child = crossover(selected_population[parents[0]], selected_population[parents[1]])
        offspring.append(child)
    return np.array(offspring)

# Мутация потомков с новыми гиперпараметрами
def mutate(offspring, mutation_rate, mutation_strength, mutation_percent_genes, mutation_by_replacement, x_range):
    num_to_mutate = int(len(offspring) * mutation_rate)
    indices_to_mutate = np.random.choice(len(offspring), num_to_mutate, replace=False)
    for i in indices_to_mutate:
        num_genes_to_mutate = int(offspring.shape[1] * mutation_percent_genes)
        genes_to_mutate = np.random.choice(offspring.shape[1], num_genes_to_mutate, replace=False)
        for gene_idx in genes_to_mutate:
            if mutation_by_replacement:
                offspring[i, gene_idx] = np.random.uniform(x_range[0], x_range[1])
            else:
                mutation = np.random.uniform(-mutation_strength, mutation_strength) * (x_range[1] - x_range[0])
                offspring[i, gene_idx] += mutation
                offspring[i, gene_idx] = np.clip(offspring[i, gene_idx], x_range[0], x_range[1])
    return offspring

# Оптимизация генетического алгоритма
class GeneticAlgorithmOptimizer:
    def __init__(self, param_ranges, population_size, offspring_ratio, mutation_rate, mutation_strength, mutation_percent_genes,
                 mutation_by_replacement, elite_fraction, initialization_method, selection_percentage, early_stopping_patience, generations=400):
        self.param_ranges = param_ranges
        self.population_size = population_size
        self.offspring_ratio = offspring_ratio
        self.mutation_rate = mutation_rate
        self.mutation_strength = mutation_strength
        self.mutation_percent_genes = mutation_percent_genes
        self.mutation_by_replacement = mutation_by_replacement
        self.elite_fraction = elite_fraction
        self.initialization_method = initialization_method
        self.selection_percentage = selection_percentage
        self.early_stopping_patience = early_stopping_patience
        self.generations = generations
    
    def optimize(self):
        population = initialize_population(self.population_size, (-500, 500), 10, method=self.initialization_method)
        fitness_values = np.array([cached_objective_function(ind) for ind in population])

        best_solution = None
        best_fitness = float('inf')
        no_improvement_count = 0

        global_start_time = time.time()

        for generation in range(self.generations):
            selected_population, selected_fitness = select_top_individuals_with_elitism(
                population, fitness_values, self.selection_percentage, elite_count=int(self.elite_fraction * self.population_size)
            )
            num_offspring = int(len(selected_population) * self.offspring_ratio)
            offspring = generate_offspring(selected_population, num_offspring)
            offspring = mutate(offspring, self.mutation_rate, self.mutation_strength, self.mutation_percent_genes,
                               self.mutation_by_replacement, (-500, 500))

            combined_population = np.concatenate([selected_population, offspring])
            combined_fitness = np.array([cached_objective_function(ind) for ind in combined_population])

            final_population, final_fitness = select_top_individuals_with_elitism(
                combined_population, combined_fitness, self.population_size / len(combined_population),
                elite_count=int(self.elite_fraction * self.population_size)
            )

            population = final_population
            fitness_values = final_fitness

            current_best_fitness = np.min(final_fitness)
            current_best_solution = final_population[np.argmin(final_fitness)]

            if current_best_fitness < best_fitness:
                best_fitness = current_best_fitness
                best_solution = current_best_solution
                no_improvement_count = 0
            else:
                no_improvement_count += 1

            if no_improvement_count >= self.early_stopping_patience:
                # print(f"Early stopping на {generation+1} итерации.")
                break

        elapsed_time = time.time() - global_start_time
        return best_solution, best_fitness, generation + 1, elapsed_time

# Генерация случайных гиперпараметров
def generate_random_hyperparameters():
    hyperparameters = {
        "population_size": random.randint(100, 500),
        "offspring_ratio": random.uniform(1.5, 3.0),
        "mutation_rate": random.uniform(0.1, 0.5),
        "mutation_strength": random.uniform(0.1, 0.5),
        "mutation_percent_genes": random.uniform(0.1, 0.2),
        "mutation_by_replacement": random.choice([True]),
        "elite_fraction": random.uniform(0.05, 0.2),
        "initialization_method": random.choice(['random', 'lhs'])
    }
    return hyperparameters

# Количество внешних и внутренних прогонов
num_outer_runs = 10
num_inner_runs = 30
summary_results = []
header_saved = False
csv_filename = 'cust_shvefel_upd.csv'

# Внешний цикл для различных гиперпараметров
for outer_run in range(num_outer_runs):
    print(f"\n=== Внешний прогон {outer_run + 1} ===\n")
    
    hyperparams = generate_random_hyperparameters()
    
    results = []

    # Внутренний цикл для одного набора гиперпараметров
    for inner_run in range(num_inner_runs):
        optimizer = GeneticAlgorithmOptimizer(
            param_ranges={
                "x0": (-500, 500),
                "x1": (-500, 500),
                "x2": (-500, 500),
                "x3": (-500, 500),
                "x4": (-500, 500),
                "x5": (-500, 500),
                "x6": (-500, 500),
                "x7": (-500, 500),
                "x8": (-500, 500),
                "x9": (-500, 500),
            },
            **hyperparams,
            generations=400,
            selection_percentage=0.5,
            early_stopping_patience=30
        )

        best_solution, best_fitness, best_generation, best_generation_time = optimizer.optimize()

        run_data = {
            'Значение функции Швефеля': best_fitness,
            'Лучшая итерация': best_generation,
            'Время до лучшей итерации': best_generation_time
        }
        results.append(run_data)

    df_results = pd.DataFrame(results)
    median_fitness = df_results['Значение функции Швефеля'].median()
    mode_iteration = df_results['Лучшая итерация'].mode()[0]

    summary_row = {
        'Медиана значения функции Швефеля': median_fitness,
        'Мода лучшей итерации': mode_iteration,
        'Медиана времени до лучшей итерации': df_results['Время до лучшей итерации'].median()
    }

    for param, value in hyperparams.items():
        summary_row[param] = value

    # Добавляем строку в csv-файл
    df_summary_row = pd.DataFrame([summary_row])
    df_summary_row.to_csv(csv_filename, mode='a', header=not header_saved, index=False, float_format='%.6f')
    header_saved = True  # Чтобы сохранить заголовок только один раз

    # Вывод строки перед записью в файл (или после)
    print(f"Результаты для внешнего прогона {outer_run + 1}:")
    print(df_summary_row.to_string(index=False))

    # Очистка кэша и ручное удаление крупных объектов
    cached_objective_function.clear_cache()
    del df_results, df_summary_row, results
    gc.collect()

# Итоговая таблица не создается, поскольку все записывается в файл
print(f"\nВсе результаты сохранены в файл '{csv_filename}'.")
# Out:
# === Внешний прогон 1 ===
#
# Результаты для внешнего прогона 1:
#  Медиана значения функции Швефеля  Мода лучшей итерации  Медиана времени до лучшей итерации  population_size  offspring_ratio  mutation_rate  mutation_strength  mutation_percent_genes  mutation_by_replacement  elite_fraction initialization_method
#                          0.173398                   400                             2.14051              100         1.870012       0.455752           0.197684                0.151147                     True        0.051635                   lhs
#
# === Внешний прогон 2 ===
#
# Результаты для внешнего прогона 2:
#  Медиана значения функции Швефеля  Мода лучшей итерации  Медиана времени до лучшей итерации  population_size  offspring_ratio  mutation_rate  mutation_strength  mutation_percent_genes  mutation_by_replacement  elite_fraction initialization_method
#                          0.148847                   400                            3.022013              142         2.268315       0.223683           0.392644                 0.15525                     True        0.095908                random
#
# === Внешний прогон 3 ===
#
# Результаты для внешнего прогона 3:
#  Медиана значения функции Швефеля  Мода лучшей итерации  Медиана времени до лучшей итерации  population_size  offspring_ratio  mutation_rate  mutation_strength  mutation_percent_genes  mutation_by_replacement  elite_fraction initialization_method
#                          0.047157                   400                            7.285546              277         2.387494       0.338473           0.122717                0.118656                     True        0.072841                random
#
# === Внешний прогон 4 ===
#
# Результаты для внешнего прогона 4:
#  Медиана значения функции Швефеля  Мода лучшей итерации  Медиана времени до лучшей итерации  population_size  offspring_ratio  mutation_rate  mutation_strength  mutation_percent_genes  mutation_by_replacement  elite_fraction initialization_method
#                          0.035615                   400                            7.842551              338         1.901181       0.495118           0.454058                0.139427                     True        0.183513                   lhs
#
# === Внешний прогон 5 ===
#
# Результаты для внешнего прогона 5:
#  Медиана значения функции Швефеля  Мода лучшей итерации  Медиана времени до лучшей итерации  population_size  offspring_ratio  mutation_rate  mutation_strength  mutation_percent_genes  mutation_by_replacement  elite_fraction initialization_method
#                          0.152796                   400                            2.151509              106         1.837516       0.390096           0.263217                0.144186                     True        0.059194                   lhs
#
# === Внешний прогон 6 ===
#
# Результаты для внешнего прогона 6:
#  Медиана значения функции Швефеля  Мода лучшей итерации  Медиана времени до лучшей итерации  population_size  offspring_ratio  mutation_rate  mutation_strength  mutation_percent_genes  mutation_by_replacement  elite_fraction initialization_method
#                          0.024618                   400                            6.971216              226         2.685551       0.459602           0.249233                0.151033                     True        0.053156                   lhs
#
# === Внешний прогон 7 ===
#
# Результаты для внешнего прогона 7:
#  Медиана значения функции Швефеля  Мода лучшей итерации  Медиана времени до лучшей итерации  population_size  offspring_ratio  mutation_rate  mutation_strength  mutation_percent_genes  mutation_by_replacement  elite_fraction initialization_method
#                          0.048359                   400                             9.19205              384         2.158148       0.181542            0.41249                0.195715                     True        0.157364                   lhs
#
# === Внешний прогон 8 ===
#
# Результаты для внешнего прогона 8:
#  Медиана значения функции Швефеля  Мода лучшей итерации  Медиана времени до лучшей итерации  population_size  offspring_ratio  mutation_rate  mutation_strength  mutation_percent_genes  mutation_by_replacement  elite_fraction initialization_method
#                          0.021006                   400                             8.52765              264         2.973889       0.347237           0.332743                0.195454                     True        0.180069                   lhs
#
# === Внешний прогон 9 ===
#
# Результаты для внешнего прогона 9:
#  Медиана значения функции Швефеля  Мода лучшей итерации  Медиана времени до лучшей итерации  population_size  offspring_ratio  mutation_rate  mutation_strength  mutation_percent_genes  mutation_by_replacement  elite_fraction initialization_method
#                          0.425673                   400                            3.330017              204         1.517605       0.234978           0.444651                 0.11286                     True        0.144113                random
#
# === Внешний прогон 10 ===
#
# Результаты для внешнего прогона 10:
#  Медиана значения функции Швефеля  Мода лучшей итерации  Медиана времени до лучшей итерации  population_size  offspring_ratio  mutation_rate  mutation_strength  mutation_percent_genes  mutation_by_replacement  elite_fraction initialization_method
#                          0.023683                   400                            9.205062              331         2.585475       0.293396           0.451092                0.140768                     True         0.17231                random
#
# Все результаты сохранены в файл 'cust_shvefel_upd.csv'.
